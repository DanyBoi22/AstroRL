# %%
import numpy as np
from ipynb.fs.full.forcemodel import IForceModel, GravityForce
from ipynb.fs.full.integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from ipynb.fs.full.env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.helpers import save_states, load_states
from ipynb.fs.full.analysis import numerical_analysis

# %%
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10,
        1.5e10,
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.4], #[-0.97, 0.243],
        [0.0, 0.0], 
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432],
        [-0.932, -0.864], 
    ]),
    # Names
    np.array([
        "One",
        "Two",
        "Three",
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue",
        "green",
    ]),
]

# %%
dt=0.001
n_steps=100000
states = run_simulation(GravityForce, SymplecticEuler, bodies, dt=dt, n_steps=n_steps, records_len=100000)
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body unstable solution simulation trace", save_path="threebodyeulervisunstable.pdf") #, save_path="threebodyeulervis.pdf")
#save_states(f"states_3body_(dt{dt}st{int(n_steps/1000)}k_euler.json", states)

# %%
#states = load_states("states_3body_(dt0.001st10000k_euler.json")
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body stable solution simulation trace", save_path=None) #, save_path="threebodyeulervis.pdf")
numerical_analysis(states)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 states = load_states("states_3body_(dt0.001st10000k_euler.json")
#       2 plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body stable solution simulation trace", save_path="threebodyeulervis.pdf") #
# ----> 3 numerical_analysis(states)
#
# File D:\Desktop\jupo\src\analysis.ipynb:215, in numerical_analysis(states)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "6a713289-8fc5-4a97-8b62-b873b0a16a8f",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import matplotlib.pyplot as plt\n",
#      12     "from matplotlib.animation import FuncAnimation\n",
#      13     "import math\n",
#      14     "import json\n",
#      15     "from IPython.display import HTML"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "2f7a19c8-4e19-4afc-a9e2-b24b2dbcf211",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "def load_states(path):\n",
#      26     "    with open(path, \"r\") as f:\n",
#      27     "        states = json.load(f)\n",
#      28     "\n",
#      29     "    # Optional: convert back to NumPy\n",
#      30     "    for s in states:\n",
#      31     "        s[\"x\"] = np.array(s[\"x\"])\n",
#      32     "        s[\"v\"] = np.array(s[\"v\"])\n",
#      33     "        s[\"a\"] = np.array(s[\"a\"])\n",
#      34     "        s[\"m\"] = np.array(s[\"m\"])\n",
#      35     "    return states"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": 3,
#      41    "id": "f308c365-dc88-4fe4-9478-5b6cf121bbce",
#      42    "metadata": {},
#      43    "outputs": [],
#      44    "source": [
#      45     "\"\"\"\n",
#      46     "def total_energy(x, v, m, G=6.67430e-11):\n",
#      47     "    KE = 0.5 * np.sum(m[:, None] * np.sum(v**2, axis=1))\n",
#      48     "    PE = 0.0\n",
#      49     "    N = len(m)\n",
#      50     "    for i in range(N):\n",
#      51     "        for j in range(i+1, N):\n",
#      52     "            r = np.linalg.norm(x[i] - x[j])\n",
#      53     "            if r == 0:\n",
#      54     "                continue\n",
#      55     "            else:\n",
#      56     "                PE -= G * m[i] * m[j] / r\n",
#      57     "    return KE + PE\n",
#      58     "\"\"\"\n",
#      59     "def total_energy(x, v, m, G=6.67430e-11):\n",
#      60     "    x = np.asarray(x)\n",
#      61     "    v = np.asarray(v)\n",
#      62     "    m = np.asarray(m)\n",
#      63     "\n",
#      64     "    if x.ndim == 2:\n",
#      65     "        # single frame\n",
#      66     "        KE = 0.5 * np.sum(m * np.sum(v**2, axis=1))\n",
#      67     "\n",
#      68     "        PE = 0.0\n",
#      69     "        N = len(m)\n",
#      70     "        for i in range(N):\n",
#      71     "            for j in range(i+1, N):\n",
#      72     "                r = np.linalg.norm(x[i] - x[j])\n",
#      73     "                if r > 0:\n",
#      74     "                    PE -= G * m[i] * m[j] / r\n",
#      75     "\n",
#      76     "        return KE + PE\n",
#      77     "\n",
#      78     "    elif x.ndim == 3:\n",
#      79     "        # multiple frames\n",
#      80     "        KE = 0.5 * np.sum(m[None, :] * np.sum(v**2, axis=2), axis=1)\n",
#      81     "\n",
#      82     "        PE = np.zeros(x.shape[0])\n",
#      83     "        N = len(m)\n",
#      84     "        for i in range(N):\n",
#      85     "            for j in range(i+1, N):\n",
#      86     "                r = np.linalg.norm(x[:, i, :] - x[:, j, :], axis=1)\n",
#      87     "                mask = r > 0\n",
#      88     "                PE[mask] -= G * m[i] * m[j] / r[mask]\n",
#      89     "\n",
#      90     "        return KE + PE\n",
#      91     "\n",
#      92     "    else:\n",
#      93     "        raise ValueError(\"x and v must have shape (N,2) or (T,N,2)\")\n",
#      94     "\n",
#      95     "\"\"\"\n",
#      96     "def total_angular_momentum(x, v, m):\n",
#      97     "    L = np.zeros(3)\n",
#      98     "    for i in range(len(m)):\n",
#      99     "        r3 = np.array([x[i,0], x[i,1], 0])\n",
#     100     "        v3 = np.array([v[i,0], v[i,1], 0])\n",
#     101     "        L += m[i] * np.cross(r3, v3)\n",
#     102     "    return np.linalg.norm(L)\n",
#     103     "\"\"\"\n",
#     104     "\n",
#     105     "def total_angular_momentum(x, v, m):\n",
#     106     "    # barycentric adjustment\n",
#     107     "    x = np.asarray(x)\n",
#     108     "    v = np.asarray(v)\n",
#     109     "    m = np.asarray(m)\n",
#     110     "\n",
#     111     "    M = np.sum(m)\n",
#     112     "\n",
#     113     "    if x.ndim == 2:\n",
#     114     "        # single frame\n",
#     115     "        r_cm = np.sum(m[:, None] * x, axis=0) / M\n",
#     116     "        v_cm = np.sum(m[:, None] * v, axis=0) / M\n",
#     117     "\n",
#     118     "        L = np.zeros(3)\n",
#     119     "        for i in range(len(m)):\n",
#     120     "            r3 = np.array([x[i,0] - r_cm[0], x[i,1] - r_cm[1], 0.0])\n",
#     121     "            v3 = np.array([v[i,0] - v_cm[0], v[i,1] - v_cm[1], 0.0])\n",
#     122     "            L += m[i] * np.cross(r3, v3)\n",
#     123     "\n",
#     124     "        return np.linalg.norm(L)\n",
#     125     "\n",
#     126     "    elif x.ndim == 3:\n",
#     127     "        # multiple frames\n",
#     128     "        r_cm = np.sum(m[None, :, None] * x, axis=1) / M\n",
#     129     "        v_cm = np.sum(m[None, :, None] * v, axis=1) / M\n",
#     130     "\n",
#     131     "        L = np.zeros((x.shape[0], 3))\n",
#     132     "        for i in range(len(m)):\n",
#     133     "            r3 = np.zeros((x.shape[0], 3))\n",
#     134     "            v3 = np.zeros((x.shape[0], 3))\n",
#     135     "\n",
#     136     "            r3[:, :2] = x[:, i, :] - r_cm\n",
#     137     "            v3[:, :2] = v[:, i, :] - v_cm\n",
#     138     "\n",
#     139     "            L += m[i] * np.cross(r3, v3)\n",
#     140     "\n",
#     141     "        return np.linalg.norm(L, axis=1)\n",
#     142     "\n",
#     143     "    else:\n",
#     144     "        raise ValueError(\"x and v must have shape (N,2) or (T,N,2)\")\n",
#     145     "\n",
#     146     "\"\"\"\n",
#     147     "def total_linear_momentum(v, m): \n",
#     148     "    P = np.sum(m[:, None] * v, axis=0) \n",
#     149     "    return np.linalg.norm(P)\n",
#     150     "\"\"\"\n",
#     151     "\n",
#     152     "def total_linear_momentum(v, m):\n",
#     153     "    v = np.asarray(v)\n",
#     154     "    m = np.asarray(m)\n",
#     155     "\n",
#     156     "    if v.ndim == 2:\n",
#     157     "        # single frame: (N, D)\n",
#     158     "        P = np.sum(m[:, None] * v, axis=0)\n",
#     159     "        return np.linalg.norm(P)\n",
#     160     "\n",
#     161     "    elif v.ndim == 3:\n",
#     162     "        # multiple frames: (T, N, D)\n",
#     163     "        P = np.sum(m[None, :, None] * v, axis=1)\n",
#     164     "        return np.linalg.norm(P, axis=1)\n",
#     165     "\n",
#     166     "    else:\n",
#     167     "        raise ValueError(\"v must have shape (N,D) or (T,N,D)\")\n",
#     168     "\n",
#     169     "\"\"\"\n",
#     170     "def center_of_mass(x, m):\n",
#     171     "    return np.linalg.norm(np.sum(m[:,None] * x, axis=0) / np.sum(m))\n",
#     172     "\"\"\"\n",
#     173     "\n",
#     174     "def center_of_mass(x, m):\n",
#     175     "    x = np.asarray(x)\n",
#     176     "    m = np.asarray(m)\n",
#     177     "\n",
#     178     "    if x.ndim == 2:\n",
#     179     "        r_cm = np.sum(m[:, None] * x, axis=0) / np.sum(m)\n",
#     180     "        return np.linalg.norm(r_cm)\n",
#     181     "\n",
#     182     "    elif x.ndim == 3:\n",
#     183     "        r_cm = np.sum(m[None, :, None] * x, axis=1) / np.sum(m)\n",
#     184     "        return np.linalg.norm(r_cm, axis=1)\n",
#     185     "\n",
#     186     "    else:\n",
#     187     "        raise ValueError(\"x must have shape (N,2) or (T,N,2)\")\n",
#     188     "\n"
#     189    ]
#     190   },
#     191   {
#     192    "cell_type": "code",
#     193    "execution_count": 4,
#     194    "id": "be436f78-4ea4-4c68-a580-931520702881",
#     195    "metadata": {},
#     196    "outputs": [],
#     197    "source": [
#     198     "def plot_energy_error(errors, t, save_path):\n",
#     199     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     200     "    ax.set_xlabel(\"Time [s]\")\n",
#     201     "    ax.set_ylabel(\"Total Energy Difference [J]\")\n",
#     202     "    ax.set_title(\"Total Energy Error over time\")\n",
#     203     "    ax.plot(t, errors)\n",
#     204     "    plt.savefig(save_path) \n",
#     205     "    plt.show()\n",
#     206     "\n",
#     207     "def plot_total_angular_momentum(dL, t, save_path):\n",
#     208     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     209     "    ax.set_xlabel(\"Time [s]\")\n",
#     210     "    ax.set_ylabel(\"Total Angular Momentum Difference [kg·m²/s]\")\n",
#     211     "    ax.set_title(\"Total Angular Momentum Drift over time\")\n",
#     212     "    ax.plot(t, dL)\n",
#     213     "    plt.savefig(save_path) \n",
#     214     "    plt.show()\n",
# --> 215     "\n",
#     216     "def plot_total_linear_momentum(dM, t, save_path):\n",
#     217     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     218     "    ax.set_xlabel(\"Time [s]\")\n",
#     219     "    ax.set_ylabel(\"Total Linear Momentum Difference [kg·m/s]\")\n",
#     220     "    ax.set_title(\"Total Linear Momentum Drift over time\")\n",
#     221     "    ax.plot(t, dM)\n",
#     222     "    plt.savefig(save_path) \n",
#     223     "    plt.show()\n",
#     224     "\n",
#     225     "def plot_center_of_mass(com, t, save_path): \n",
#     226     "    plt.figure(figsize=(12,6))\n",
#     227     "    plt.plot(t, com)\n",
#     228     "    plt.xlabel(\"Time [s]\")\n",
#     229     "    plt.ylabel(\"Distance from origin [m]\")\n",
#     230     "    plt.title(\"Center of Mass Magnitude Drift over time\")\n",
#     231     "    plt.savefig(save_path) \n",
#     232     "    plt.show()"
#     233    ]
#     234   },
#     235   {
#     236    "cell_type": "code",
#     237    "execution_count": 5,
#     238    "id": "56fbb188-eef8-4509-a396-b4d5e7436fae",
#     239    "metadata": {},
#     240    "outputs": [],
#     241    "source": [
#     242     "def numerical_analysis(states):\n",
#     243     "    t = [s['t'] for s in states]\n",
#     244     "\n",
#     245     "    E0 = total_energy(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     246     "    errors = [(total_energy(s['x'], s['v'], s['m']) - E0) / (abs(E0) if abs(E0) != 0 else 1) for s in states]\n",
#     247     "    plot_energy_error(errors, t, \"energy_error.pdf\")\n",
#     248     "    \n",
#     249     "    L0 = total_angular_momentum(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     250     "    dL = [(total_angular_momentum(s['x'], s['v'],states[0]['m']) - L0) / (abs(L0) if abs(L0) != 0 else 1) for s in states]\n",
#     251     "    plot_total_angular_momentum(dL, t, \"angular_momentum.pdf\")\n",
#     252     "    \n",
#     253     "    M0 = total_linear_momentum(states[0]['v'], states[0]['m'])\n",
#     254     "    dM = [(total_linear_momentum(s['v'], s['m']) - M0) / (abs(M0) if abs(M0) != 0 else 1) for s in states]\n",
#     255     "    plot_total_linear_momentum(dM, t, \"linear_momentum.pdf\")\n",
#     256     "    \n",
#     257     "    #com = np.linalg.norm([center_of_mass(s[\"x\"], s[\"m\"]) for s in states], axis=1)\n",
#     258     "    com = [center_of_mass(s[\"x\"], s[\"m\"]) for s in states]\n",
#     259     "    plot_center_of_mass(com, t, \"com.pdf\")\n",
#     260     "    #COM = center_of_mass(x, m)"
#     261    ]
#     262   },
#     263   {
#     264    "cell_type": "code",
#     265    "execution_count": 6,
#     266    "id": "59a9589c-6f1b-4011-8932-0b428c952062",
#     267    "metadata": {},
#     268    "outputs": [],
#     269    "source": [
#     270     "def body_characteristics(state, G=6.67430e-11, centre_index=None):\n",
#     271     "    \"\"\"\n",
#     272     "    Compute characteristic values per body for one state.\n",
#     273     "    Returns a list of dicts, one per body.\n",
#     274     "    \"\"\"\n",
#     275     "    x = state['x']\n",
#     276     "    v = state['v']\n",
#     277     "    m = state['m']\n",
#     278     "    N = len(m)\n",
#     279     "\n",
#     280     "    # Optional centering\n",
#     281     "    if centre_index is not None:\n",
#     282     "        x = x - x[centre_index]\n",
#     283     "        v = v - v[centre_index]\n",
#     284     "\n",
#     285     "    chars = []\n",
#     286     "\n",
#     287     "    for i in range(N):\n",
#     288     "\n",
#     289     "        # absolute velocity\n",
#     290     "        speed = np.linalg.norm(v[i])\n",
#     291     "        # linear momentum\n",
#     292     "        p_mag =  np.linalg.norm(m[i] * v[i])\n",
#     293     "\n",
#     294     "        # Angular momentum \n",
#     295     "        #L = m[i] * (x[i][0]*v[i][1] - x[i][1]*v[i][0]) #(z-component)\n",
#     296     "        r3 = np.array([x[i,0], x[i,1], 0])\n",
#     297     "        v3 = np.array([v[i,0], v[i,1], 0])\n",
#     298     "        L = m[i] * np.cross(r3, v3)\n",
#     299     "        L = np.linalg.norm(L)\n",
#     300     "\n",
#     301     "        kinetic = 0.5 * m[i] * speed**2\n",
#     302     "\n",
#     303     "        # Potential energy\n",
#     304     "        potential = 0.0\n",
#     305     "        for j in range(N):\n",
#     306     "            if i == j:\n",
#     307     "                continue\n",
#     308     "            r = np.linalg.norm(x[j] - x[i])\n",
#     309     "            potential -= 0.5 * G * m[i] * m[j] / r\n",
#     310     "\n",
#     311     "        #potential = np.abs(potential)\n",
#     312     "\n",
#     313     "        chars.append({\n",
#     314     "            \"speed\": speed,\n",
#     315     "            \"momentum\": p_mag,\n",
#     316     "            \"angular_momentum\": L,\n",
#     317     "            \"kinetic_energy\": kinetic,\n",
#     318     "            \"potential_energy\": potential,\n",
#     319     "            \"total_energy\": kinetic + potential\n",
#     320     "        })\n",
#     321     "\n",
#     322     "    return chars"
#     323    ]
#     324   },
#     325   {
#     326    "cell_type": "code",
#     327    "execution_count": 7,
#     328    "id": "363ff636-3e8e-4e53-b9b1-95c1242433d8",
#     329    "metadata": {},
#     330    "outputs": [],
#     331    "source": [
#     332     "def visual_analysis(states, body_names, colors=None, scale=1.0/1.496e11, inspect_body=None, centre_body=None, trail_length=50,\n",
#     333     "                         xlim=(-10,10), ylim=(-10,10), interval=50, save_path=None):\n",
#     334     "    \"\"\"\n",
#     335     "    Visualize a precomputed trajectory of bodies with center on the Sun (0,0).\n",
#     336     "\n",
#     337     "    states : list of dict\n",
#     338     "        Each dict must contain 'x' (Nx2 array) and 't' (float).\n",
#     339     "    body_names : list of str\n",
#     340     "        Names of bodies (length N).\n",
#     341     "    colors : list of str \n",
#     342     "        Colors for bodies.\n",
#     343     "    scale : float\n",
#     344     "        Scaling factor for positions.\n",
#     345     "    centre_body : str\n",
#     346     "        name of the body from body_names list to centre the visualisation around\n",
#     347     "    trail_length : int\n",
#     348     "        How many past positions to show in trail.\n",
#     349     "    xlim, ylim : tuple\n",
#     350     "        Plot limits.\n",
#     351     "    interval : int\n",
#     352     "        Milliseconds between frames.\n",
#     353     "    save_path : str or None\n",
#     354     "        If given, saves animation to file (requires ffmpeg).\n",
#     355     "    \"\"\"\n",
#     356     "    colors = colors\n",
#     357     "    n_bodies = len(body_names)\n",
#     358     "\n",
#     359     "    if((inspect_body is not None) and (inspect_body in body_names)):\n",
#     360     "        inspect_index = np.where(body_names == inspect_body)[0][0]\n",
#     361     "    else:\n",
#     362     "        inspect_index = None\n",
#     363     "    \n",
#     364     "    if((centre_body is not None) and (centre_body in body_names)):\n",
#     365     "        centre_body_index = np.where(body_names == centre_body)[0][0]\n",
#     366     "    else:\n",
#     367     "        centre_body_index = None\n",
#     368     "\n",
#     369     "    # TODO: states preproc: scale and offset calc\n",
#     370     "    \n",
#     371     "    # Figure setup\n",
#     372     "    fig, ax = plt.subplots(figsize=(12,12))\n",
#     373     "    ax.set_aspect(\"equal\")\n",
#     374     "    ax.set_xlim(*xlim)\n",
#     375     "    ax.set_ylim(*ylim)\n",
#     376     "    ax.set_xlabel(\"x (scaled)\")\n",
#     377     "    ax.set_ylabel(\"y (scaled)\")\n",
#     378     "    ax.set_title(\"Sol System\")\n",
#     379     "    \n",
#     380     "    #Scatter objects for bodies positions\n",
#     381     "    scatters = [ax.scatter([], [], color=colors[i], s=80, label=body_names[i]) for i in range(n_bodies)]\n",
#     382     "\n",
#     383     "    # Time text\n",
#     384     "    time_text = ax.text(0.02, 0.98, \"\", transform=ax.transAxes, ha=\"left\", va=\"top\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.6, edgecolor=\"none\"))\n",
#     385     "\n",
#     386     "    # Body info text\n",
#     387     "    info_text = ax.text(0.02, 0.02, \"\", transform=ax.transAxes, ha=\"left\", va=\"bottom\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.7, edgecolor=\"none\"))\n",
#     388     "\n",
#     389     "    \n",
#     390     "    def init():    \n",
#     391     "        if(centre_body_index is not None):\n",
#     392     "            centre_body_offset = states[0]['x'][centre_body_index]\n",
#     393     "        else:\n",
#     394     "            centre_body_offset = 0\n",
#     395     "            \n",
#     396     "        positions = (states[0]['x'] - centre_body_offset) * scale\n",
#     397     "        i = 0\n",
#     398     "        for sc in scatters:\n",
#     399     "            sc.set_offsets([positions[i]])\n",
#     400     "            i += 1\n",
#     401     "            \n",
#     402     "        time_text.set_text(f\"t = {states[0]['t']:.1f} s\")\n",
#     403     "\n",
#     404     "        state = states[0]\n",
#     405     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     406     "        if inspect_index:\n",
#     407     "            c = chars[inspect_index]\n",
#     408     "        else: \n",
#     409     "            c = chars[centre_body_index]\n",
#     410     "\n",
#     411     "        info_text.set_text(\n",
#     412     "            f\"{inspect_body}\\n\"\n",
#     413     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     414     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     415     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     416     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     417     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     418     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     419     "        )\n",
#     420     "\n",
#     421     "        return tuple(scatters) + (time_text, info_text)\n",
#     422     "\n",
#     423     "    \n",
#     424     "    def update(frame):\n",
#     425     "        state = states[frame]\n",
#     426     "        \n",
#     427     "        if(centre_body_index is not None):\n",
#     428     "            centre_body_offset = state['x'][centre_body_index]\n",
#     429     "        else:\n",
#     430     "            centre_body_offset = 0\n",
#     431     "        \n",
#     432     "        positions = (state['x'] - centre_body_offset) * scale\n",
#     433     "        t = state['t']\n",
#     434     "\n",
#     435     "        # Update bodies positions\n",
#     436     "        for i, name in enumerate(body_names):\n",
#     437     "            scatters[i].set_offsets([positions[i]])\n",
#     438     "\n",
#     439     "        # Update time\n",
#     440     "        time_text.set_text(f\"t = {t:.1f} s\")\n",
#     441     "\n",
#     442     "        # Update info \n",
#     443     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     444     "        if inspect_index:\n",
#     445     "            c = chars[inspect_index]\n",
#     446     "        else: \n",
#     447     "            c = chars[centre_body_index]\n",
#     448     "\n",
#     449     "        info_text.set_text(\n",
#     450     "            f\"{inspect_body}\\n\"\n",
#     451     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     452     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     453     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     454     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     455     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     456     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     457     "        )\n",
#     458     "\n",
#     459     "        return tuple(scatters) + (time_text, info_text)\n",
#     460     "\n",
#     461     "    \n",
#     462     "    anim = FuncAnimation(fig, update, frames=len(states), init_func=init, blit=False, interval=interval)\n",
#     463     "\n",
#     464     "    plt.legend()\n",
#     465     "\n",
#     466     "    if save_path is not None:\n",
#     467     "        anim.save(save_path, writer=\"pillow\")\n",
#     468     "\n",
#     469     "    return anim"
#     470    ]
#     471   },
#     472   {
#     473    "cell_type": "code",
#     474    "execution_count": 8,
#     475    "id": "ea5b3b50-b869-4749-8ed0-89ef4d9d5734",
#     476    "metadata": {},
#     477    "outputs": [],
#     478    "source": [
#     479     "bodies = [\n",
#     480     "    np.array([\n",
#     481     "        \"AntiMercury\",\n",
#     482     "        \"Mercury\",\n",
#     483     "    ]),\n",
#     484     "    # Colors (reasonable defaults for visualization)\n",
#     485     "    np.array([\n",
#     486     "        \"red\",        # Sun\n",
#     487     "        \"blue\",          # Mercury\n",
#     488     "    ]),\n",
#     489     "]\n",
#     490     "\n",
#     491     "#anim = visual_analysis(states=states, body_names=bodies[0], colors=bodies[1], inspect_body=\"Mercury\", interval=200, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), save_path=\"2_body_analysis.gif\")"
#     492    ]
#     493   }
#     494  ],
#     495  "metadata": {
#     496   "kernelspec": {
#     497    "display_name": "Python 3 (ipykernel)",
#     498    "language": "python",
#     499    "name": "python3"
#     500   },
#     501   "language_info": {
#     502    "codemirror_mode": {
#     503     "name": "ipython",
#     504     "version": 3
#     505    },
#     506    "file_extension": ".py",
#     507    "mimetype": "text/x-python",
#     508    "name": "python",
#     509    "nbconvert_exporter": "python",
#     510    "pygments_lexer": "ipython3",
#     511    "version": "3.11.5"
#     512   }
#     513  },
#     514  "nbformat": 4,
#     515  "nbformat_minor": 5
#     516 }
#
# File D:\Desktop\jupo\src\analysis.ipynb:215, in <listcomp>(.0)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "6a713289-8fc5-4a97-8b62-b873b0a16a8f",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import matplotlib.pyplot as plt\n",
#      12     "from matplotlib.animation import FuncAnimation\n",
#      13     "import math\n",
#      14     "import json\n",
#      15     "from IPython.display import HTML"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "2f7a19c8-4e19-4afc-a9e2-b24b2dbcf211",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "def load_states(path):\n",
#      26     "    with open(path, \"r\") as f:\n",
#      27     "        states = json.load(f)\n",
#      28     "\n",
#      29     "    # Optional: convert back to NumPy\n",
#      30     "    for s in states:\n",
#      31     "        s[\"x\"] = np.array(s[\"x\"])\n",
#      32     "        s[\"v\"] = np.array(s[\"v\"])\n",
#      33     "        s[\"a\"] = np.array(s[\"a\"])\n",
#      34     "        s[\"m\"] = np.array(s[\"m\"])\n",
#      35     "    return states"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": 3,
#      41    "id": "f308c365-dc88-4fe4-9478-5b6cf121bbce",
#      42    "metadata": {},
#      43    "outputs": [],
#      44    "source": [
#      45     "\"\"\"\n",
#      46     "def total_energy(x, v, m, G=6.67430e-11):\n",
#      47     "    KE = 0.5 * np.sum(m[:, None] * np.sum(v**2, axis=1))\n",
#      48     "    PE = 0.0\n",
#      49     "    N = len(m)\n",
#      50     "    for i in range(N):\n",
#      51     "        for j in range(i+1, N):\n",
#      52     "            r = np.linalg.norm(x[i] - x[j])\n",
#      53     "            if r == 0:\n",
#      54     "                continue\n",
#      55     "            else:\n",
#      56     "                PE -= G * m[i] * m[j] / r\n",
#      57     "    return KE + PE\n",
#      58     "\"\"\"\n",
#      59     "def total_energy(x, v, m, G=6.67430e-11):\n",
#      60     "    x = np.asarray(x)\n",
#      61     "    v = np.asarray(v)\n",
#      62     "    m = np.asarray(m)\n",
#      63     "\n",
#      64     "    if x.ndim == 2:\n",
#      65     "        # single frame\n",
#      66     "        KE = 0.5 * np.sum(m * np.sum(v**2, axis=1))\n",
#      67     "\n",
#      68     "        PE = 0.0\n",
#      69     "        N = len(m)\n",
#      70     "        for i in range(N):\n",
#      71     "            for j in range(i+1, N):\n",
#      72     "                r = np.linalg.norm(x[i] - x[j])\n",
#      73     "                if r > 0:\n",
#      74     "                    PE -= G * m[i] * m[j] / r\n",
#      75     "\n",
#      76     "        return KE + PE\n",
#      77     "\n",
#      78     "    elif x.ndim == 3:\n",
#      79     "        # multiple frames\n",
#      80     "        KE = 0.5 * np.sum(m[None, :] * np.sum(v**2, axis=2), axis=1)\n",
#      81     "\n",
#      82     "        PE = np.zeros(x.shape[0])\n",
#      83     "        N = len(m)\n",
#      84     "        for i in range(N):\n",
#      85     "            for j in range(i+1, N):\n",
#      86     "                r = np.linalg.norm(x[:, i, :] - x[:, j, :], axis=1)\n",
#      87     "                mask = r > 0\n",
#      88     "                PE[mask] -= G * m[i] * m[j] / r[mask]\n",
#      89     "\n",
#      90     "        return KE + PE\n",
#      91     "\n",
#      92     "    else:\n",
#      93     "        raise ValueError(\"x and v must have shape (N,2) or (T,N,2)\")\n",
#      94     "\n",
#      95     "\"\"\"\n",
#      96     "def total_angular_momentum(x, v, m):\n",
#      97     "    L = np.zeros(3)\n",
#      98     "    for i in range(len(m)):\n",
#      99     "        r3 = np.array([x[i,0], x[i,1], 0])\n",
#     100     "        v3 = np.array([v[i,0], v[i,1], 0])\n",
#     101     "        L += m[i] * np.cross(r3, v3)\n",
#     102     "    return np.linalg.norm(L)\n",
#     103     "\"\"\"\n",
#     104     "\n",
#     105     "def total_angular_momentum(x, v, m):\n",
#     106     "    # barycentric adjustment\n",
#     107     "    x = np.asarray(x)\n",
#     108     "    v = np.asarray(v)\n",
#     109     "    m = np.asarray(m)\n",
#     110     "\n",
#     111     "    M = np.sum(m)\n",
#     112     "\n",
#     113     "    if x.ndim == 2:\n",
#     114     "        # single frame\n",
#     115     "        r_cm = np.sum(m[:, None] * x, axis=0) / M\n",
#     116     "        v_cm = np.sum(m[:, None] * v, axis=0) / M\n",
#     117     "\n",
#     118     "        L = np.zeros(3)\n",
#     119     "        for i in range(len(m)):\n",
#     120     "            r3 = np.array([x[i,0] - r_cm[0], x[i,1] - r_cm[1], 0.0])\n",
#     121     "            v3 = np.array([v[i,0] - v_cm[0], v[i,1] - v_cm[1], 0.0])\n",
#     122     "            L += m[i] * np.cross(r3, v3)\n",
#     123     "\n",
#     124     "        return np.linalg.norm(L)\n",
#     125     "\n",
#     126     "    elif x.ndim == 3:\n",
#     127     "        # multiple frames\n",
#     128     "        r_cm = np.sum(m[None, :, None] * x, axis=1) / M\n",
#     129     "        v_cm = np.sum(m[None, :, None] * v, axis=1) / M\n",
#     130     "\n",
#     131     "        L = np.zeros((x.shape[0], 3))\n",
#     132     "        for i in range(len(m)):\n",
#     133     "            r3 = np.zeros((x.shape[0], 3))\n",
#     134     "            v3 = np.zeros((x.shape[0], 3))\n",
#     135     "\n",
#     136     "            r3[:, :2] = x[:, i, :] - r_cm\n",
#     137     "            v3[:, :2] = v[:, i, :] - v_cm\n",
#     138     "\n",
#     139     "            L += m[i] * np.cross(r3, v3)\n",
#     140     "\n",
#     141     "        return np.linalg.norm(L, axis=1)\n",
#     142     "\n",
#     143     "    else:\n",
#     144     "        raise ValueError(\"x and v must have shape (N,2) or (T,N,2)\")\n",
#     145     "\n",
#     146     "\"\"\"\n",
#     147     "def total_linear_momentum(v, m): \n",
#     148     "    P = np.sum(m[:, None] * v, axis=0) \n",
#     149     "    return np.linalg.norm(P)\n",
#     150     "\"\"\"\n",
#     151     "\n",
#     152     "def total_linear_momentum(v, m):\n",
#     153     "    v = np.asarray(v)\n",
#     154     "    m = np.asarray(m)\n",
#     155     "\n",
#     156     "    if v.ndim == 2:\n",
#     157     "        # single frame: (N, D)\n",
#     158     "        P = np.sum(m[:, None] * v, axis=0)\n",
#     159     "        return np.linalg.norm(P)\n",
#     160     "\n",
#     161     "    elif v.ndim == 3:\n",
#     162     "        # multiple frames: (T, N, D)\n",
#     163     "        P = np.sum(m[None, :, None] * v, axis=1)\n",
#     164     "        return np.linalg.norm(P, axis=1)\n",
#     165     "\n",
#     166     "    else:\n",
#     167     "        raise ValueError(\"v must have shape (N,D) or (T,N,D)\")\n",
#     168     "\n",
#     169     "\"\"\"\n",
#     170     "def center_of_mass(x, m):\n",
#     171     "    return np.linalg.norm(np.sum(m[:,None] * x, axis=0) / np.sum(m))\n",
#     172     "\"\"\"\n",
#     173     "\n",
#     174     "def center_of_mass(x, m):\n",
#     175     "    x = np.asarray(x)\n",
#     176     "    m = np.asarray(m)\n",
#     177     "\n",
#     178     "    if x.ndim == 2:\n",
#     179     "        r_cm = np.sum(m[:, None] * x, axis=0) / np.sum(m)\n",
#     180     "        return np.linalg.norm(r_cm)\n",
#     181     "\n",
#     182     "    elif x.ndim == 3:\n",
#     183     "        r_cm = np.sum(m[None, :, None] * x, axis=1) / np.sum(m)\n",
#     184     "        return np.linalg.norm(r_cm, axis=1)\n",
#     185     "\n",
#     186     "    else:\n",
#     187     "        raise ValueError(\"x must have shape (N,2) or (T,N,2)\")\n",
#     188     "\n"
#     189    ]
#     190   },
#     191   {
#     192    "cell_type": "code",
#     193    "execution_count": 4,
#     194    "id": "be436f78-4ea4-4c68-a580-931520702881",
#     195    "metadata": {},
#     196    "outputs": [],
#     197    "source": [
#     198     "def plot_energy_error(errors, t, save_path):\n",
#     199     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     200     "    ax.set_xlabel(\"Time [s]\")\n",
#     201     "    ax.set_ylabel(\"Total Energy Difference [J]\")\n",
#     202     "    ax.set_title(\"Total Energy Error over time\")\n",
#     203     "    ax.plot(t, errors)\n",
#     204     "    plt.savefig(save_path) \n",
#     205     "    plt.show()\n",
#     206     "\n",
#     207     "def plot_total_angular_momentum(dL, t, save_path):\n",
#     208     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     209     "    ax.set_xlabel(\"Time [s]\")\n",
#     210     "    ax.set_ylabel(\"Total Angular Momentum Difference [kg·m²/s]\")\n",
#     211     "    ax.set_title(\"Total Angular Momentum Drift over time\")\n",
#     212     "    ax.plot(t, dL)\n",
#     213     "    plt.savefig(save_path) \n",
#     214     "    plt.show()\n",
# --> 215     "\n",
#     216     "def plot_total_linear_momentum(dM, t, save_path):\n",
#     217     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     218     "    ax.set_xlabel(\"Time [s]\")\n",
#     219     "    ax.set_ylabel(\"Total Linear Momentum Difference [kg·m/s]\")\n",
#     220     "    ax.set_title(\"Total Linear Momentum Drift over time\")\n",
#     221     "    ax.plot(t, dM)\n",
#     222     "    plt.savefig(save_path) \n",
#     223     "    plt.show()\n",
#     224     "\n",
#     225     "def plot_center_of_mass(com, t, save_path): \n",
#     226     "    plt.figure(figsize=(12,6))\n",
#     227     "    plt.plot(t, com)\n",
#     228     "    plt.xlabel(\"Time [s]\")\n",
#     229     "    plt.ylabel(\"Distance from origin [m]\")\n",
#     230     "    plt.title(\"Center of Mass Magnitude Drift over time\")\n",
#     231     "    plt.savefig(save_path) \n",
#     232     "    plt.show()"
#     233    ]
#     234   },
#     235   {
#     236    "cell_type": "code",
#     237    "execution_count": 5,
#     238    "id": "56fbb188-eef8-4509-a396-b4d5e7436fae",
#     239    "metadata": {},
#     240    "outputs": [],
#     241    "source": [
#     242     "def numerical_analysis(states):\n",
#     243     "    t = [s['t'] for s in states]\n",
#     244     "\n",
#     245     "    E0 = total_energy(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     246     "    errors = [(total_energy(s['x'], s['v'], s['m']) - E0) / (abs(E0) if abs(E0) != 0 else 1) for s in states]\n",
#     247     "    plot_energy_error(errors, t, \"energy_error.pdf\")\n",
#     248     "    \n",
#     249     "    L0 = total_angular_momentum(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     250     "    dL = [(total_angular_momentum(s['x'], s['v'],states[0]['m']) - L0) / (abs(L0) if abs(L0) != 0 else 1) for s in states]\n",
#     251     "    plot_total_angular_momentum(dL, t, \"angular_momentum.pdf\")\n",
#     252     "    \n",
#     253     "    M0 = total_linear_momentum(states[0]['v'], states[0]['m'])\n",
#     254     "    dM = [(total_linear_momentum(s['v'], s['m']) - M0) / (abs(M0) if abs(M0) != 0 else 1) for s in states]\n",
#     255     "    plot_total_linear_momentum(dM, t, \"linear_momentum.pdf\")\n",
#     256     "    \n",
#     257     "    #com = np.linalg.norm([center_of_mass(s[\"x\"], s[\"m\"]) for s in states], axis=1)\n",
#     258     "    com = [center_of_mass(s[\"x\"], s[\"m\"]) for s in states]\n",
#     259     "    plot_center_of_mass(com, t, \"com.pdf\")\n",
#     260     "    #COM = center_of_mass(x, m)"
#     261    ]
#     262   },
#     263   {
#     264    "cell_type": "code",
#     265    "execution_count": 6,
#     266    "id": "59a9589c-6f1b-4011-8932-0b428c952062",
#     267    "metadata": {},
#     268    "outputs": [],
#     269    "source": [
#     270     "def body_characteristics(state, G=6.67430e-11, centre_index=None):\n",
#     271     "    \"\"\"\n",
#     272     "    Compute characteristic values per body for one state.\n",
#     273     "    Returns a list of dicts, one per body.\n",
#     274     "    \"\"\"\n",
#     275     "    x = state['x']\n",
#     276     "    v = state['v']\n",
#     277     "    m = state['m']\n",
#     278     "    N = len(m)\n",
#     279     "\n",
#     280     "    # Optional centering\n",
#     281     "    if centre_index is not None:\n",
#     282     "        x = x - x[centre_index]\n",
#     283     "        v = v - v[centre_index]\n",
#     284     "\n",
#     285     "    chars = []\n",
#     286     "\n",
#     287     "    for i in range(N):\n",
#     288     "\n",
#     289     "        # absolute velocity\n",
#     290     "        speed = np.linalg.norm(v[i])\n",
#     291     "        # linear momentum\n",
#     292     "        p_mag =  np.linalg.norm(m[i] * v[i])\n",
#     293     "\n",
#     294     "        # Angular momentum \n",
#     295     "        #L = m[i] * (x[i][0]*v[i][1] - x[i][1]*v[i][0]) #(z-component)\n",
#     296     "        r3 = np.array([x[i,0], x[i,1], 0])\n",
#     297     "        v3 = np.array([v[i,0], v[i,1], 0])\n",
#     298     "        L = m[i] * np.cross(r3, v3)\n",
#     299     "        L = np.linalg.norm(L)\n",
#     300     "\n",
#     301     "        kinetic = 0.5 * m[i] * speed**2\n",
#     302     "\n",
#     303     "        # Potential energy\n",
#     304     "        potential = 0.0\n",
#     305     "        for j in range(N):\n",
#     306     "            if i == j:\n",
#     307     "                continue\n",
#     308     "            r = np.linalg.norm(x[j] - x[i])\n",
#     309     "            potential -= 0.5 * G * m[i] * m[j] / r\n",
#     310     "\n",
#     311     "        #potential = np.abs(potential)\n",
#     312     "\n",
#     313     "        chars.append({\n",
#     314     "            \"speed\": speed,\n",
#     315     "            \"momentum\": p_mag,\n",
#     316     "            \"angular_momentum\": L,\n",
#     317     "            \"kinetic_energy\": kinetic,\n",
#     318     "            \"potential_energy\": potential,\n",
#     319     "            \"total_energy\": kinetic + potential\n",
#     320     "        })\n",
#     321     "\n",
#     322     "    return chars"
#     323    ]
#     324   },
#     325   {
#     326    "cell_type": "code",
#     327    "execution_count": 7,
#     328    "id": "363ff636-3e8e-4e53-b9b1-95c1242433d8",
#     329    "metadata": {},
#     330    "outputs": [],
#     331    "source": [
#     332     "def visual_analysis(states, body_names, colors=None, scale=1.0/1.496e11, inspect_body=None, centre_body=None, trail_length=50,\n",
#     333     "                         xlim=(-10,10), ylim=(-10,10), interval=50, save_path=None):\n",
#     334     "    \"\"\"\n",
#     335     "    Visualize a precomputed trajectory of bodies with center on the Sun (0,0).\n",
#     336     "\n",
#     337     "    states : list of dict\n",
#     338     "        Each dict must contain 'x' (Nx2 array) and 't' (float).\n",
#     339     "    body_names : list of str\n",
#     340     "        Names of bodies (length N).\n",
#     341     "    colors : list of str \n",
#     342     "        Colors for bodies.\n",
#     343     "    scale : float\n",
#     344     "        Scaling factor for positions.\n",
#     345     "    centre_body : str\n",
#     346     "        name of the body from body_names list to centre the visualisation around\n",
#     347     "    trail_length : int\n",
#     348     "        How many past positions to show in trail.\n",
#     349     "    xlim, ylim : tuple\n",
#     350     "        Plot limits.\n",
#     351     "    interval : int\n",
#     352     "        Milliseconds between frames.\n",
#     353     "    save_path : str or None\n",
#     354     "        If given, saves animation to file (requires ffmpeg).\n",
#     355     "    \"\"\"\n",
#     356     "    colors = colors\n",
#     357     "    n_bodies = len(body_names)\n",
#     358     "\n",
#     359     "    if((inspect_body is not None) and (inspect_body in body_names)):\n",
#     360     "        inspect_index = np.where(body_names == inspect_body)[0][0]\n",
#     361     "    else:\n",
#     362     "        inspect_index = None\n",
#     363     "    \n",
#     364     "    if((centre_body is not None) and (centre_body in body_names)):\n",
#     365     "        centre_body_index = np.where(body_names == centre_body)[0][0]\n",
#     366     "    else:\n",
#     367     "        centre_body_index = None\n",
#     368     "\n",
#     369     "    # TODO: states preproc: scale and offset calc\n",
#     370     "    \n",
#     371     "    # Figure setup\n",
#     372     "    fig, ax = plt.subplots(figsize=(12,12))\n",
#     373     "    ax.set_aspect(\"equal\")\n",
#     374     "    ax.set_xlim(*xlim)\n",
#     375     "    ax.set_ylim(*ylim)\n",
#     376     "    ax.set_xlabel(\"x (scaled)\")\n",
#     377     "    ax.set_ylabel(\"y (scaled)\")\n",
#     378     "    ax.set_title(\"Sol System\")\n",
#     379     "    \n",
#     380     "    #Scatter objects for bodies positions\n",
#     381     "    scatters = [ax.scatter([], [], color=colors[i], s=80, label=body_names[i]) for i in range(n_bodies)]\n",
#     382     "\n",
#     383     "    # Time text\n",
#     384     "    time_text = ax.text(0.02, 0.98, \"\", transform=ax.transAxes, ha=\"left\", va=\"top\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.6, edgecolor=\"none\"))\n",
#     385     "\n",
#     386     "    # Body info text\n",
#     387     "    info_text = ax.text(0.02, 0.02, \"\", transform=ax.transAxes, ha=\"left\", va=\"bottom\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.7, edgecolor=\"none\"))\n",
#     388     "\n",
#     389     "    \n",
#     390     "    def init():    \n",
#     391     "        if(centre_body_index is not None):\n",
#     392     "            centre_body_offset = states[0]['x'][centre_body_index]\n",
#     393     "        else:\n",
#     394     "            centre_body_offset = 0\n",
#     395     "            \n",
#     396     "        positions = (states[0]['x'] - centre_body_offset) * scale\n",
#     397     "        i = 0\n",
#     398     "        for sc in scatters:\n",
#     399     "            sc.set_offsets([positions[i]])\n",
#     400     "            i += 1\n",
#     401     "            \n",
#     402     "        time_text.set_text(f\"t = {states[0]['t']:.1f} s\")\n",
#     403     "\n",
#     404     "        state = states[0]\n",
#     405     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     406     "        if inspect_index:\n",
#     407     "            c = chars[inspect_index]\n",
#     408     "        else: \n",
#     409     "            c = chars[centre_body_index]\n",
#     410     "\n",
#     411     "        info_text.set_text(\n",
#     412     "            f\"{inspect_body}\\n\"\n",
#     413     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     414     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     415     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     416     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     417     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     418     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     419     "        )\n",
#     420     "\n",
#     421     "        return tuple(scatters) + (time_text, info_text)\n",
#     422     "\n",
#     423     "    \n",
#     424     "    def update(frame):\n",
#     425     "        state = states[frame]\n",
#     426     "        \n",
#     427     "        if(centre_body_index is not None):\n",
#     428     "            centre_body_offset = state['x'][centre_body_index]\n",
#     429     "        else:\n",
#     430     "            centre_body_offset = 0\n",
#     431     "        \n",
#     432     "        positions = (state['x'] - centre_body_offset) * scale\n",
#     433     "        t = state['t']\n",
#     434     "\n",
#     435     "        # Update bodies positions\n",
#     436     "        for i, name in enumerate(body_names):\n",
#     437     "            scatters[i].set_offsets([positions[i]])\n",
#     438     "\n",
#     439     "        # Update time\n",
#     440     "        time_text.set_text(f\"t = {t:.1f} s\")\n",
#     441     "\n",
#     442     "        # Update info \n",
#     443     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     444     "        if inspect_index:\n",
#     445     "            c = chars[inspect_index]\n",
#     446     "        else: \n",
#     447     "            c = chars[centre_body_index]\n",
#     448     "\n",
#     449     "        info_text.set_text(\n",
#     450     "            f\"{inspect_body}\\n\"\n",
#     451     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     452     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     453     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     454     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     455     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     456     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     457     "        )\n",
#     458     "\n",
#     459     "        return tuple(scatters) + (time_text, info_text)\n",
#     460     "\n",
#     461     "    \n",
#     462     "    anim = FuncAnimation(fig, update, frames=len(states), init_func=init, blit=False, interval=interval)\n",
#     463     "\n",
#     464     "    plt.legend()\n",
#     465     "\n",
#     466     "    if save_path is not None:\n",
#     467     "        anim.save(save_path, writer=\"pillow\")\n",
#     468     "\n",
#     469     "    return anim"
#     470    ]
#     471   },
#     472   {
#     473    "cell_type": "code",
#     474    "execution_count": 8,
#     475    "id": "ea5b3b50-b869-4749-8ed0-89ef4d9d5734",
#     476    "metadata": {},
#     477    "outputs": [],
#     478    "source": [
#     479     "bodies = [\n",
#     480     "    np.array([\n",
#     481     "        \"AntiMercury\",\n",
#     482     "        \"Mercury\",\n",
#     483     "    ]),\n",
#     484     "    # Colors (reasonable defaults for visualization)\n",
#     485     "    np.array([\n",
#     486     "        \"red\",        # Sun\n",
#     487     "        \"blue\",          # Mercury\n",
#     488     "    ]),\n",
#     489     "]\n",
#     490     "\n",
#     491     "#anim = visual_analysis(states=states, body_names=bodies[0], colors=bodies[1], inspect_body=\"Mercury\", interval=200, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), save_path=\"2_body_analysis.gif\")"
#     492    ]
#     493   }
#     494  ],
#     495  "metadata": {
#     496   "kernelspec": {
#     497    "display_name": "Python 3 (ipykernel)",
#     498    "language": "python",
#     499    "name": "python3"
#     500   },
#     501   "language_info": {
#     502    "codemirror_mode": {
#     503     "name": "ipython",
#     504     "version": 3
#     505    },
#     506    "file_extension": ".py",
#     507    "mimetype": "text/x-python",
#     508    "name": "python",
#     509    "nbconvert_exporter": "python",
#     510    "pygments_lexer": "ipython3",
#     511    "version": "3.11.5"
#     512   }
#     513  },
#     514  "nbformat": 4,
#     515  "nbformat_minor": 5
#     516 }
#
# File D:\Desktop\jupo\src\analysis.ipynb:102, in total_angular_momentum(x, v, m)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "6a713289-8fc5-4a97-8b62-b873b0a16a8f",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import matplotlib.pyplot as plt\n",
#      12     "from matplotlib.animation import FuncAnimation\n",
#      13     "import math\n",
#      14     "import json\n",
#      15     "from IPython.display import HTML"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "2f7a19c8-4e19-4afc-a9e2-b24b2dbcf211",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "def load_states(path):\n",
#      26     "    with open(path, \"r\") as f:\n",
#      27     "        states = json.load(f)\n",
#      28     "\n",
#      29     "    # Optional: convert back to NumPy\n",
#      30     "    for s in states:\n",
#      31     "        s[\"x\"] = np.array(s[\"x\"])\n",
#      32     "        s[\"v\"] = np.array(s[\"v\"])\n",
#      33     "        s[\"a\"] = np.array(s[\"a\"])\n",
#      34     "        s[\"m\"] = np.array(s[\"m\"])\n",
#      35     "    return states"
#      36    ]
#      37   },
#      38   {
#      39    "cell_type": "code",
#      40    "execution_count": 3,
#      41    "id": "f308c365-dc88-4fe4-9478-5b6cf121bbce",
#      42    "metadata": {},
#      43    "outputs": [],
#      44    "source": [
#      45     "\"\"\"\n",
#      46     "def total_energy(x, v, m, G=6.67430e-11):\n",
#      47     "    KE = 0.5 * np.sum(m[:, None] * np.sum(v**2, axis=1))\n",
#      48     "    PE = 0.0\n",
#      49     "    N = len(m)\n",
#      50     "    for i in range(N):\n",
#      51     "        for j in range(i+1, N):\n",
#      52     "            r = np.linalg.norm(x[i] - x[j])\n",
#      53     "            if r == 0:\n",
#      54     "                continue\n",
#      55     "            else:\n",
#      56     "                PE -= G * m[i] * m[j] / r\n",
# ...
#     172     "\"\"\"\n",
#     173     "\n",
#     174     "def center_of_mass(x, m):\n",
#     175     "    x = np.asarray(x)\n",
#     176     "    m = np.asarray(m)\n",
#     177     "\n",
#     178     "    if x.ndim == 2:\n",
#     179     "        r_cm = np.sum(m[:, None] * x, axis=0) / np.sum(m)\n",
#     180     "        return np.linalg.norm(r_cm)\n",
#     181     "\n",
#     182     "    elif x.ndim == 3:\n",
#     183     "        r_cm = np.sum(m[None, :, None] * x, axis=1) / np.sum(m)\n",
#     184     "        return np.linalg.norm(r_cm, axis=1)\n",
#     185     "\n",
#     186     "    else:\n",
#     187     "        raise ValueError(\"x must have shape (N,2) or (T,N,2)\")\n",
#     188     "\n"
#     189    ]
#     190   },
#     191   {
#     192    "cell_type": "code",
#     193    "execution_count": 4,
#     194    "id": "be436f78-4ea4-4c68-a580-931520702881",
#     195    "metadata": {},
#     196    "outputs": [],
#     197    "source": [
#     198     "def plot_energy_error(errors, t, save_path):\n",
#     199     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     200     "    ax.set_xlabel(\"Time [s]\")\n",
#     201     "    ax.set_ylabel(\"Total Energy Difference [J]\")\n",
#     202     "    ax.set_title(\"Total Energy Error over time\")\n",
#     203     "    ax.plot(t, errors)\n",
#     204     "    plt.savefig(save_path) \n",
#     205     "    plt.show()\n",
#     206     "\n",
#     207     "def plot_total_angular_momentum(dL, t, save_path):\n",
#     208     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     209     "    ax.set_xlabel(\"Time [s]\")\n",
#     210     "    ax.set_ylabel(\"Total Angular Momentum Difference [kg·m²/s]\")\n",
#     211     "    ax.set_title(\"Total Angular Momentum Drift over time\")\n",
#     212     "    ax.plot(t, dL)\n",
#     213     "    plt.savefig(save_path) \n",
#     214     "    plt.show()\n",
#     215     "\n",
#     216     "def plot_total_linear_momentum(dM, t, save_path):\n",
#     217     "    fig, ax = plt.subplots(figsize=(12,6))\n",
#     218     "    ax.set_xlabel(\"Time [s]\")\n",
#     219     "    ax.set_ylabel(\"Total Linear Momentum Difference [kg·m/s]\")\n",
#     220     "    ax.set_title(\"Total Linear Momentum Drift over time\")\n",
#     221     "    ax.plot(t, dM)\n",
#     222     "    plt.savefig(save_path) \n",
#     223     "    plt.show()\n",
#     224     "\n",
#     225     "def plot_center_of_mass(com, t, save_path): \n",
#     226     "    plt.figure(figsize=(12,6))\n",
#     227     "    plt.plot(t, com)\n",
#     228     "    plt.xlabel(\"Time [s]\")\n",
#     229     "    plt.ylabel(\"Distance from origin [m]\")\n",
#     230     "    plt.title(\"Center of Mass Magnitude Drift over time\")\n",
#     231     "    plt.savefig(save_path) \n",
#     232     "    plt.show()"
#     233    ]
#     234   },
#     235   {
#     236    "cell_type": "code",
#     237    "execution_count": 5,
#     238    "id": "56fbb188-eef8-4509-a396-b4d5e7436fae",
#     239    "metadata": {},
#     240    "outputs": [],
#     241    "source": [
#     242     "def numerical_analysis(states):\n",
#     243     "    t = [s['t'] for s in states]\n",
#     244     "\n",
#     245     "    E0 = total_energy(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     246     "    errors = [(total_energy(s['x'], s['v'], s['m']) - E0) / (abs(E0) if abs(E0) != 0 else 1) for s in states]\n",
#     247     "    plot_energy_error(errors, t, \"energy_error.pdf\")\n",
#     248     "    \n",
#     249     "    L0 = total_angular_momentum(states[0]['x'], states[0]['v'], states[0]['m'])\n",
#     250     "    dL = [(total_angular_momentum(s['x'], s['v'],states[0]['m']) - L0) / (abs(L0) if abs(L0) != 0 else 1) for s in states]\n",
#     251     "    plot_total_angular_momentum(dL, t, \"angular_momentum.pdf\")\n",
#     252     "    \n",
#     253     "    M0 = total_linear_momentum(states[0]['v'], states[0]['m'])\n",
#     254     "    dM = [(total_linear_momentum(s['v'], s['m']) - M0) / (abs(M0) if abs(M0) != 0 else 1) for s in states]\n",
#     255     "    plot_total_linear_momentum(dM, t, \"linear_momentum.pdf\")\n",
#     256     "    \n",
#     257     "    #com = np.linalg.norm([center_of_mass(s[\"x\"], s[\"m\"]) for s in states], axis=1)\n",
#     258     "    com = [center_of_mass(s[\"x\"], s[\"m\"]) for s in states]\n",
#     259     "    plot_center_of_mass(com, t, \"com.pdf\")\n",
#     260     "    #COM = center_of_mass(x, m)"
#     261    ]
#     262   },
#     263   {
#     264    "cell_type": "code",
#     265    "execution_count": 6,
#     266    "id": "59a9589c-6f1b-4011-8932-0b428c952062",
#     267    "metadata": {},
#     268    "outputs": [],
#     269    "source": [
#     270     "def body_characteristics(state, G=6.67430e-11, centre_index=None):\n",
#     271     "    \"\"\"\n",
#     272     "    Compute characteristic values per body for one state.\n",
#     273     "    Returns a list of dicts, one per body.\n",
#     274     "    \"\"\"\n",
#     275     "    x = state['x']\n",
#     276     "    v = state['v']\n",
#     277     "    m = state['m']\n",
#     278     "    N = len(m)\n",
#     279     "\n",
#     280     "    # Optional centering\n",
#     281     "    if centre_index is not None:\n",
#     282     "        x = x - x[centre_index]\n",
#     283     "        v = v - v[centre_index]\n",
#     284     "\n",
#     285     "    chars = []\n",
#     286     "\n",
#     287     "    for i in range(N):\n",
#     288     "\n",
#     289     "        # absolute velocity\n",
#     290     "        speed = np.linalg.norm(v[i])\n",
#     291     "        # linear momentum\n",
#     292     "        p_mag =  np.linalg.norm(m[i] * v[i])\n",
#     293     "\n",
#     294     "        # Angular momentum \n",
#     295     "        #L = m[i] * (x[i][0]*v[i][1] - x[i][1]*v[i][0]) #(z-component)\n",
#     296     "        r3 = np.array([x[i,0], x[i,1], 0])\n",
#     297     "        v3 = np.array([v[i,0], v[i,1], 0])\n",
#     298     "        L = m[i] * np.cross(r3, v3)\n",
#     299     "        L = np.linalg.norm(L)\n",
#     300     "\n",
#     301     "        kinetic = 0.5 * m[i] * speed**2\n",
#     302     "\n",
#     303     "        # Potential energy\n",
#     304     "        potential = 0.0\n",
#     305     "        for j in range(N):\n",
#     306     "            if i == j:\n",
#     307     "                continue\n",
#     308     "            r = np.linalg.norm(x[j] - x[i])\n",
#     309     "            potential -= 0.5 * G * m[i] * m[j] / r\n",
#     310     "\n",
#     311     "        #potential = np.abs(potential)\n",
#     312     "\n",
#     313     "        chars.append({\n",
#     314     "            \"speed\": speed,\n",
#     315     "            \"momentum\": p_mag,\n",
#     316     "            \"angular_momentum\": L,\n",
#     317     "            \"kinetic_energy\": kinetic,\n",
#     318     "            \"potential_energy\": potential,\n",
#     319     "            \"total_energy\": kinetic + potential\n",
#     320     "        })\n",
#     321     "\n",
#     322     "    return chars"
#     323    ]
#     324   },
#     325   {
#     326    "cell_type": "code",
#     327    "execution_count": 7,
#     328    "id": "363ff636-3e8e-4e53-b9b1-95c1242433d8",
#     329    "metadata": {},
#     330    "outputs": [],
#     331    "source": [
#     332     "def visual_analysis(states, body_names, colors=None, scale=1.0/1.496e11, inspect_body=None, centre_body=None, trail_length=50,\n",
#     333     "                         xlim=(-10,10), ylim=(-10,10), interval=50, save_path=None):\n",
#     334     "    \"\"\"\n",
#     335     "    Visualize a precomputed trajectory of bodies with center on the Sun (0,0).\n",
#     336     "\n",
#     337     "    states : list of dict\n",
#     338     "        Each dict must contain 'x' (Nx2 array) and 't' (float).\n",
#     339     "    body_names : list of str\n",
#     340     "        Names of bodies (length N).\n",
#     341     "    colors : list of str \n",
#     342     "        Colors for bodies.\n",
#     343     "    scale : float\n",
#     344     "        Scaling factor for positions.\n",
#     345     "    centre_body : str\n",
#     346     "        name of the body from body_names list to centre the visualisation around\n",
#     347     "    trail_length : int\n",
#     348     "        How many past positions to show in trail.\n",
#     349     "    xlim, ylim : tuple\n",
#     350     "        Plot limits.\n",
#     351     "    interval : int\n",
#     352     "        Milliseconds between frames.\n",
#     353     "    save_path : str or None\n",
#     354     "        If given, saves animation to file (requires ffmpeg).\n",
#     355     "    \"\"\"\n",
#     356     "    colors = colors\n",
#     357     "    n_bodies = len(body_names)\n",
#     358     "\n",
#     359     "    if((inspect_body is not None) and (inspect_body in body_names)):\n",
#     360     "        inspect_index = np.where(body_names == inspect_body)[0][0]\n",
#     361     "    else:\n",
#     362     "        inspect_index = None\n",
#     363     "    \n",
#     364     "    if((centre_body is not None) and (centre_body in body_names)):\n",
#     365     "        centre_body_index = np.where(body_names == centre_body)[0][0]\n",
#     366     "    else:\n",
#     367     "        centre_body_index = None\n",
#     368     "\n",
#     369     "    # TODO: states preproc: scale and offset calc\n",
#     370     "    \n",
#     371     "    # Figure setup\n",
#     372     "    fig, ax = plt.subplots(figsize=(12,12))\n",
#     373     "    ax.set_aspect(\"equal\")\n",
#     374     "    ax.set_xlim(*xlim)\n",
#     375     "    ax.set_ylim(*ylim)\n",
#     376     "    ax.set_xlabel(\"x (scaled)\")\n",
#     377     "    ax.set_ylabel(\"y (scaled)\")\n",
#     378     "    ax.set_title(\"Sol System\")\n",
#     379     "    \n",
#     380     "    #Scatter objects for bodies positions\n",
#     381     "    scatters = [ax.scatter([], [], color=colors[i], s=80, label=body_names[i]) for i in range(n_bodies)]\n",
#     382     "\n",
#     383     "    # Time text\n",
#     384     "    time_text = ax.text(0.02, 0.98, \"\", transform=ax.transAxes, ha=\"left\", va=\"top\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.6, edgecolor=\"none\"))\n",
#     385     "\n",
#     386     "    # Body info text\n",
#     387     "    info_text = ax.text(0.02, 0.02, \"\", transform=ax.transAxes, ha=\"left\", va=\"bottom\", fontsize=9, bbox=dict(facecolor=\"white\", alpha=0.7, edgecolor=\"none\"))\n",
#     388     "\n",
#     389     "    \n",
#     390     "    def init():    \n",
#     391     "        if(centre_body_index is not None):\n",
#     392     "            centre_body_offset = states[0]['x'][centre_body_index]\n",
#     393     "        else:\n",
#     394     "            centre_body_offset = 0\n",
#     395     "            \n",
#     396     "        positions = (states[0]['x'] - centre_body_offset) * scale\n",
#     397     "        i = 0\n",
#     398     "        for sc in scatters:\n",
#     399     "            sc.set_offsets([positions[i]])\n",
#     400     "            i += 1\n",
#     401     "            \n",
#     402     "        time_text.set_text(f\"t = {states[0]['t']:.1f} s\")\n",
#     403     "\n",
#     404     "        state = states[0]\n",
#     405     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     406     "        if inspect_index:\n",
#     407     "            c = chars[inspect_index]\n",
#     408     "        else: \n",
#     409     "            c = chars[centre_body_index]\n",
#     410     "\n",
#     411     "        info_text.set_text(\n",
#     412     "            f\"{inspect_body}\\n\"\n",
#     413     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     414     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     415     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     416     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     417     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     418     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     419     "        )\n",
#     420     "\n",
#     421     "        return tuple(scatters) + (time_text, info_text)\n",
#     422     "\n",
#     423     "    \n",
#     424     "    def update(frame):\n",
#     425     "        state = states[frame]\n",
#     426     "        \n",
#     427     "        if(centre_body_index is not None):\n",
#     428     "            centre_body_offset = state['x'][centre_body_index]\n",
#     429     "        else:\n",
#     430     "            centre_body_offset = 0\n",
#     431     "        \n",
#     432     "        positions = (state['x'] - centre_body_offset) * scale\n",
#     433     "        t = state['t']\n",
#     434     "\n",
#     435     "        # Update bodies positions\n",
#     436     "        for i, name in enumerate(body_names):\n",
#     437     "            scatters[i].set_offsets([positions[i]])\n",
#     438     "\n",
#     439     "        # Update time\n",
#     440     "        time_text.set_text(f\"t = {t:.1f} s\")\n",
#     441     "\n",
#     442     "        # Update info \n",
#     443     "        chars = body_characteristics(state, centre_index=centre_body_index)\n",
#     444     "        if inspect_index:\n",
#     445     "            c = chars[inspect_index]\n",
#     446     "        else: \n",
#     447     "            c = chars[centre_body_index]\n",
#     448     "\n",
#     449     "        info_text.set_text(\n",
#     450     "            f\"{inspect_body}\\n\"\n",
#     451     "            f\"|v| = {c['speed']:.3e} m/s\\n\"\n",
#     452     "            f\"|p| = {c['momentum']:.3e} kg·m/s\\n\"\n",
#     453     "            f\"L = {c['angular_momentum']:.3e} kg·m²/s\\n\"\n",
#     454     "            f\"T = {c['kinetic_energy']:.3e} J\\n\"\n",
#     455     "            f\"U = {c['potential_energy']:.3e} J\\n\"\n",
#     456     "            f\"E = {c['total_energy']:.3e} J\"\n",
#     457     "        )\n",
#     458     "\n",
#     459     "        return tuple(scatters) + (time_text, info_text)\n",
#     460     "\n",
#     461     "    \n",
#     462     "    anim = FuncAnimation(fig, update, frames=len(states), init_func=init, blit=False, interval=interval)\n",
#     463     "\n",
#     464     "    plt.legend()\n",
#     465     "\n",
#     466     "    if save_path is not None:\n",
#     467     "        anim.save(save_path, writer=\"pillow\")\n",
#     468     "\n",
#     469     "    return anim"
#     470    ]
#     471   },
#     472   {
#     473    "cell_type": "code",
#     474    "execution_count": 8,
#     475    "id": "ea5b3b50-b869-4749-8ed0-89ef4d9d5734",
#     476    "metadata": {},
#     477    "outputs": [],
#     478    "source": [
#     479     "bodies = [\n",
#     480     "    np.array([\n",
#     481     "        \"AntiMercury\",\n",
#     482     "        \"Mercury\",\n",
#     483     "    ]),\n",
#     484     "    # Colors (reasonable defaults for visualization)\n",
#     485     "    np.array([\n",
#     486     "        \"red\",        # Sun\n",
#     487     "        \"blue\",          # Mercury\n",
#     488     "    ]),\n",
#     489     "]\n",
#     490     "\n",
#     491     "#anim = visual_analysis(states=states, body_names=bodies[0], colors=bodies[1], inspect_body=\"Mercury\", interval=200, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), save_path=\"2_body_analysis.gif\")"
#     492    ]
#     493   }
#     494  ],
#     495  "metadata": {
#     496   "kernelspec": {
#     497    "display_name": "Python 3 (ipykernel)",
#     498    "language": "python",
#     499    "name": "python3"
#     500   },
#     501   "language_info": {
#     502    "codemirror_mode": {
#     503     "name": "ipython",
#     504     "version": 3
#     505    },
#     506    "file_extension": ".py",
#     507    "mimetype": "text/x-python",
#     508    "name": "python",
#     509    "nbconvert_exporter": "python",
#     510    "pygments_lexer": "ipython3",
#     511    "version": "3.11.5"
#     512   }
#     513  },
#     514  "nbformat": 4,
#     515  "nbformat_minor": 5
#     516 }
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\numeric.py:1608, in cross(a, b, axisa, axisb, axisc, axis)
#    1605 cp = empty(shape, dtype)
#    1607 # recast arrays as dtype
# -> 1608 a = a.astype(dtype)
#    1609 b = b.astype(dtype)
#    1611 # create local aliases for readability
#
# KeyboardInterrupt:

# %%
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=100000)
#save_states(f"states_3body_(dt{dt}st{int(n_steps/1000)}k_verlet.json", states)

# %%
#states = load_states("states_3body_(dt0.001st10000k_verlet.json")
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body stable solution simulation trace", save_path=None)#, save_path="threebodyverletvis.pdf")
numerical_analysis(states)

# %%
#anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=40, scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), save_path=None) #save_path="3bodyproblem.gif")
#HTML(anim.to_jshtml())

# %%
#states = load_states("states_3body_extended.json")

# %%
#numerical_analysis(states)

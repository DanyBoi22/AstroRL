# %%
import numpy as np
import math
import json
import time
from IPython.display import HTML
from line_profiler import LineProfiler

from ipynb.fs.full.forcemodel import IForceModel, GravityForce
from ipynb.fs.full.integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from ipynb.fs.full.env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.helpers import save_states, load_states
from ipynb.fs.full.ship import SimpleImpulseShip, Maneuver, simple_action_space
from ipynb.fs.full.rlmontecarlo import train_mc, MonteCarloAgent, PolicyNet, compute_returns

# %%
#%load_ext line_profiler

# %% [markdown]
# Cool but unstable with really massive suns
# bodies = [
#     # Masses (kg)
#     np.array([
#         1.0e31,
#         1.0e31,
#         1.0e31,
#     ]),
#     # Positions (x, y) in meters
#     np.array([
#         [0.97e11, -0.243e11],
#         [-0.97e11, 0.243e11],
#         [0.0, 0.0],
#     ]),
#     # Velocities (vx, vy) in m/s
#     np.array([
#         [0.466e5, 0.432e5],
#         [0.466e5, 0.432e5],
#         [-0.932e5, -0.864e5],
#     ]),
#     # Names
#     np.array([
#         "One",
#         "Two",
#         "Three",
#     ]),
#     # Colors (reasonable defaults for visualization)
#     np.array([
#         "red",
#         "blue",
#         "green",
#     ]),
# ]

# %%
# This precompiles simulation for njit
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.243]
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432]
    ]),
    # Names
    np.array([
        "One",
        "Two"
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue"
    ]),
]
dt=0.0001
n_steps=1000
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=500)

# %% [markdown]
# # Monte Carlo RL with NN-Q Table #

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        7.342e22,       # Luna
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [3.844e8, 0.0],      # Luna
        [3.6e7, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 1022.0],          # Luna
        [0.0, 3055.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Moon",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "gray",       # Moon (Luna)
        "lightblue",  # Ship
    ]),
]

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [2e6, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 14000.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "lightblue",  # Ship
    ]),
]

ship_index = len(bodies[0])-1
mass = bodies[0][-1]
thrust = 1e7 # thrust changes with dt so keep that in mind
actions = simple_action_space 
safety_radius = 1e4 # on a space scale 10 km is defenitely an atmo entry
escape_dist = 1e8
#escape_dist = 6e8   
escape_vel = 1e5 
#target_dist = 1e5 # for a low lunar orbit
#target_vel = 1700 # for a low lunar orbit
target_dist = 3.6e7 # for a Far Earth orbit
target_vel = 3055.0 # for a Far Earth orbit
target_index = 0
pos_scale = 1e7
vel_scale = 1e4

n_actions = actions.n
n_episodes=100

dt=0.1
simulation_time = 3600 * 1 * 1
max_steps= int(simulation_time/dt)

reward_coef = 1.0 / max_steps

# %%
ship = SimpleImpulseShip(ship_index=ship_index, mass=mass,thrust=thrust, actions=actions, safety_radius=safety_radius, escape_dist=escape_dist, escape_vel=escape_vel, target_dist=target_dist, target_vel=target_vel, target_index=target_index, pos_scale=pos_scale, vel_scale=vel_scale, reward_coef=reward_coef)

env = SolarSystemEnv(GravityForce, VelocityVerlet, bodies, ship=ship, dt=dt)

obs0 = env.reset()
obs_dim = obs0.shape[0]

agent = MonteCarloAgent(obs_dim, n_actions)

#lp = LineProfiler()
#lp.add_function(MonteCarloAgent.run_episode)
#lp.add_function(MonteCarloAgent.update_policy)

agent = MonteCarloAgent(obs_dim, n_actions)

#lp_wrapper = lp(train_mc)
#lp_wrapper(env, agent, n_episodes=10, max_steps=10000, log_every=20, log_states=False, log_n_entries=400)

#lp.print_stats()
states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=1, log_states=True, log_n_entries=400)
#%lprun -f MonteCarloAgent.run_episode -f MonteCarloAgent.update_policy train_mc(env, agent, n_episodes=1, max_steps=1000, log_every=20, log_states=False, log_n_entries=400)
# Out:
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    1 | Return: -1.099e+00 | Loss:  1.755e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    2 | Return: -1.087e+00 | Loss:  3.128e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode    3 | Return:  9.914e+00 | Loss:  1.145e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode    4 | Return:  9.902e+00 | Loss:  4.921e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    5 | Return: -1.095e+00 | Loss:  1.475e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    6 | Return: -1.083e+00 | Loss:  7.677e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode    7 | Return:  9.914e+00 | Loss:  1.207e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode    8 | Return:  9.919e+00 | Loss:  1.754e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    9 | Return: -1.084e+00 | Loss:  1.335e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   10 | Return:  9.913e+00 | Loss: -9.198e-01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   11 | Return:  9.922e+00 | Loss: -3.145e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   12 | Return:  9.911e+00 | Loss:  1.548e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   13 | Return:  9.905e+00 | Loss:  3.227e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   14 | Return:  9.906e+00 | Loss: -3.264e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   15 | Return:  9.883e+00 | Loss:  3.620e-01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   16 | Return:  9.899e+00 | Loss:  2.130e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   17 | Return:  9.921e+00 | Loss:  7.618e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   18 | Return:  9.910e+00 | Loss:  7.720e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   19 | Return:  9.909e+00 | Loss:  5.573e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   20 | Return:  9.907e+00 | Loss:  1.551e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   21 | Return: -1.101e+00 | Loss:  9.878e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   22 | Return:  9.898e+00 | Loss:  3.281e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   23 | Return:  9.915e+00 | Loss:  4.605e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   24 | Return:  9.913e+00 | Loss:  1.767e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   25 | Return: -1.100e+00 | Loss:  1.558e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   26 | Return:  9.893e+00 | Loss:  6.284e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   27 | Return:  9.922e+00 | Loss:  5.471e-01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   28 | Return:  9.895e+00 | Loss:  8.389e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   29 | Return: -1.104e+00 | Loss:  1.832e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   30 | Return:  9.915e+00 | Loss:  2.122e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   31 | Return: -1.099e+00 | Loss:  1.258e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   32 | Return: -1.108e+00 | Loss:  7.187e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   33 | Return: -1.083e+00 | Loss:  1.166e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   34 | Return:  9.892e+00 | Loss:  8.587e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   35 | Return:  9.878e+00 | Loss:  9.844e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   36 | Return:  9.923e+00 | Loss:  4.215e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   37 | Return: -1.125e+00 | Loss:  1.973e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   38 | Return:  9.880e+00 | Loss: -5.532e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   39 | Return:  9.883e+00 | Loss:  1.470e+01
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   40 | Return:  9.902e+00 | Loss: -6.316e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   41 | Return: -1.117e+00 | Loss:  1.390e+02
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   42 | Return:  9.894e+00 | Loss:  5.649e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   43 | Return:  9.874e+00 | Loss: -7.581e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   44 | Return:  9.899e+00 | Loss:  7.168e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   45 | Return:  9.887e+00 | Loss: -9.481e+00
# Started episode
# Success: Ship reached the target
# Finished episode
# Updated policy
# Episode   46 | Return:  9.887e+00 | Loss:  4.593e-01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   47 | Return: -1.117e+00 | Loss:  8.245e+01
# Started episode

# %%
scale=1.0/4e8
centre_body="Earth"
xlim=(-0.05, 0.05)
ylim=(-0.05, 0.05)

for states_dict in states: 
    plot_static_trajectories(states=states_dict, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)

# %%
#anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=20, scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim, save_path="mcrl.gif")
#HTML(anim.to_jshtml())

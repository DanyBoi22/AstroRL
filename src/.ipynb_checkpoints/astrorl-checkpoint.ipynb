# %%
import numpy as np
import math
import json
import time
from IPython.display import HTML
from line_profiler import LineProfiler

from ipynb.fs.full.forcemodel import IForceModel, GravityForce
from ipynb.fs.full.integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from ipynb.fs.full.env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.helpers import save_states, load_states
from ipynb.fs.full.ship import SimpleImpulseShip, Maneuver, simple_action_space
from ipynb.fs.full.rlmontecarlo import train_mc, MonteCarloAgent, PolicyNet, compute_returns

# %%
#%load_ext line_profiler

# %% [markdown]
# Cool but unstable with really massive suns
# bodies = [
#     # Masses (kg)
#     np.array([
#         1.0e31,
#         1.0e31,
#         1.0e31,
#     ]),
#     # Positions (x, y) in meters
#     np.array([
#         [0.97e11, -0.243e11],
#         [-0.97e11, 0.243e11],
#         [0.0, 0.0],
#     ]),
#     # Velocities (vx, vy) in m/s
#     np.array([
#         [0.466e5, 0.432e5],
#         [0.466e5, 0.432e5],
#         [-0.932e5, -0.864e5],
#     ]),
#     # Names
#     np.array([
#         "One",
#         "Two",
#         "Three",
#     ]),
#     # Colors (reasonable defaults for visualization)
#     np.array([
#         "red",
#         "blue",
#         "green",
#     ]),
# ]

# %%
# This precompiles simulation for njit
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.243]
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432]
    ]),
    # Names
    np.array([
        "One",
        "Two"
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue"
    ]),
]
dt=0.0001
n_steps=1000
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=500)

# %% [markdown]
# # Monte Carlo RL with NN-Q Table #

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        7.342e22,       # Luna
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [3.844e8, 0.0],      # Luna
        [3.6e7, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 1022.0],          # Luna
        [0.0, 3055.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Moon",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "gray",       # Moon (Luna)
        "lightblue",  # Ship
    ]),
]

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [2e6, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 14000.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "lightblue",  # Ship
    ]),
]

ship_index = len(bodies[0])-1
mass = bodies[0][-1]

actions = simple_action_space 
safety_radius = 1e4 # on a space scale 10 km is defenitely an atmo entry
escape_dist = 1e8
#escape_dist = 6e8   
escape_vel = 1e5 
#target_dist = 1e5 # for a low lunar orbit
#target_vel = 1700 # for a low lunar orbit
target_dist = 3.6e7 # for a Far Earth orbit
target_vel = 3055.0 # for a Far Earth orbit
target_index = 0

n_actions = actions.n
n_episodes=100

dt=0.1
simulation_time = 3600 * 1 * 1
max_steps= int(simulation_time/dt)

reward_coef = 1.0 / max_steps

thrust = 1e6/dt # thrust changes with dt so keep that in mind

# %%
ship = SimpleImpulseShip(ship_index=ship_index, mass=mass,thrust=thrust, actions=actions, safety_radius=safety_radius, escape_dist=escape_dist, escape_vel=escape_vel, target_dist=target_dist, target_vel=target_vel, target_index=target_index, reward_coef=reward_coef)

env = SolarSystemEnv(GravityForce, VelocityVerlet, bodies, ship=ship, dt=dt)

obs0 = env.reset()
obs_dim = obs0.shape[0]

agent = MonteCarloAgent(obs_dim, n_actions)

#lp = LineProfiler()
#lp.add_function(MonteCarloAgent.run_episode)
#lp.add_function(MonteCarloAgent.update_policy)

agent = MonteCarloAgent(obs_dim, n_actions)

#lp_wrapper = lp(train_mc)
#lp_wrapper(env, agent, n_episodes=10, max_steps=10000, log_every=20, log_states=False, log_n_entries=400)

#lp.print_stats()
states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=1, log_states=True, log_n_entries=400)
#%lprun -f MonteCarloAgent.run_episode -f MonteCarloAgent.update_policy train_mc(env, agent, n_episodes=1, max_steps=1000, log_every=20, log_states=False, log_n_entries=400)
# Out:
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    1 | Return:  5.080e+01 | Loss:  1.176e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    2 | Return:  5.074e+01 | Loss:  1.112e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    3 | Return:  5.072e+01 | Loss:  9.905e+01
# Started episode
# Finished episode
# Updated policy
# Episode    4 | Return: -3.023e+01 | Loss:  1.004e+02
# Started episode
# Finished episode
# Updated policy
# Episode    5 | Return: -1.751e+01 | Loss:  1.092e+02
# Started episode
# Finished episode
# Updated policy
# Episode    6 | Return: -9.345e+00 | Loss:  7.699e+01
# Started episode
# Finished episode
# Updated policy
# Episode    7 | Return: -9.462e+00 | Loss:  2.917e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    8 | Return:  5.064e+01 | Loss:  5.159e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode    9 | Return:  5.067e+01 | Loss:  4.061e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   10 | Return:  5.071e+01 | Loss: -3.666e+01
# Started episode
# Finished episode
# Updated policy
# Episode   11 | Return: -1.258e+01 | Loss:  9.844e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   12 | Return:  5.069e+01 | Loss: -1.427e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   13 | Return:  5.066e+01 | Loss:  6.877e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   14 | Return:  5.073e+01 | Loss:  7.631e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   15 | Return:  5.082e+01 | Loss:  5.858e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   16 | Return:  5.083e+01 | Loss:  8.038e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   17 | Return:  5.082e+01 | Loss:  2.104e+01
# Started episode
# Finished episode
# Updated policy
# Episode   18 | Return: -7.590e+01 | Loss:  1.021e+02
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   19 | Return:  5.062e+01 | Loss:  5.089e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   20 | Return:  5.082e+01 | Loss:  2.840e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   21 | Return:  5.083e+01 | Loss:  3.116e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   22 | Return:  5.082e+01 | Loss:  2.561e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   23 | Return:  5.071e+01 | Loss:  3.837e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   24 | Return:  5.084e+01 | Loss: -2.202e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   25 | Return:  5.083e+01 | Loss: -2.255e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   26 | Return:  5.082e+01 | Loss: -4.092e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   27 | Return:  5.073e+01 | Loss: -9.372e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   28 | Return:  5.074e+01 | Loss: -2.634e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   29 | Return:  5.087e+01 | Loss:  2.799e+00
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   30 | Return:  5.080e+01 | Loss: -2.237e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   31 | Return:  5.090e+01 | Loss: -2.473e+01
# Started episode
# Failure: Ship escaped the system or exceeded system escape velocity
# Finished episode
# Updated policy
# Episode   32 | Return:  5.092e+01 | Loss: -4.994e+00
# Started episode

# %%
scale=1.0/4e8
centre_body="Earth"
xlim=(-0.05, 0.05)
ylim=(-0.05, 0.05)

for states_dict in states: 
    plot_static_trajectories(states=states_dict, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)

# %%
#anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=20, scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim, save_path="mcrl.gif")
#HTML(anim.to_jshtml())

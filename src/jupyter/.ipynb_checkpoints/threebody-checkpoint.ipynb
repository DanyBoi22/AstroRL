# %%
import numpy as np
import sys
import os
from IPython.display import HTML

from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.analysis import numerical_analysis

sys.path.append(os.path.abspath("../py"))
from forcemodel import IForceModel, GravityForce
from integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from helpers import save_states, load_states

# %%
# %load_ext autoreload
# %autoreload 2

# %%
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10,
        1.5e10,
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.4], #[-0.97, 0.243],
        [0.0, 0.0], 
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432],
        [-0.932, -0.864], 
    ]),
    # Names
    np.array([
        "One",
        "Two",
        "Three",
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue",
        "green",
    ]),
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 bodies = [
#       2     # Masses (kg)
# ----> 3     np.array([
#       4         1.5e10,
#       5         1.5e10,
#       6         1.5e10,
#       7     ]),
#       8     # Positions (x, y) in meters (approx semi-major axes on x-axis)
#       9     np.array([
#      10         [0.97, -0.243],
#      11         [-0.97, 0.4], #[-0.97, 0.243],
#      12         [0.0, 0.0],
#      13     ]),
#      14     # Velocities (vx, vy) in m/s (circular orbit approximation)
#      15     np.array([
#      16         [0.466, 0.432],
#      17         [0.466, 0.432],
#      18         [-0.932, -0.864],
#      19     ]),
#      20     # Names
#      21     np.array([
#      22         "One",
#      23         "Two",
#      24         "Three",
#      25     ]),
# ...

# %%
dt=0.001
n_steps=100000
states = run_simulation(GravityForce, SymplecticEuler, bodies, dt=dt, n_steps=n_steps, records_len=100000)
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body unstable solution simulation trace", save_path=None) #, save_path="threebodyeulervis.pdf")

# %%
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10,
        1.5e10,
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.243],
        [0.0, 0.0], 
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432],
        [-0.932, -0.864], 
    ]),
    # Names
    np.array([
        "One",
        "Two",
        "Three",
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue",
        "green",
    ]),
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 bodies = [
#       2     # Masses (kg)
# ----> 3     np.array([
#       4         1.5e10,
#       5         1.5e10,
#       6         1.5e10,
#       7     ]),
#       8     # Positions (x, y) in meters (approx semi-major axes on x-axis)
#       9     np.array([
#      10         [0.97, -0.243],
#      11         [-0.97, 0.4], #[-0.97, 0.243],
#      12         [0.0, 0.0],
#      13     ]),
#      14     # Velocities (vx, vy) in m/s (circular orbit approximation)
#      15     np.array([
#      16         [0.466, 0.432],
#      17         [0.466, 0.432],
#      18         [-0.932, -0.864],
#      19     ]),
#      20     # Names
#      21     np.array([
#      22         "One",
#      23         "Two",
#      24         "Three",
#      25     ]),
# ...

# %%
states = run_simulation(GravityForce, SymplecticEuler, bodies, dt=dt, n_steps=n_steps, records_len=100000)
#save_states(f"states_3body_(dt{dt}st{int(n_steps/1000)}k_euler.json", states)

# %%
#states = load_states("states_3body_(dt0.001st10000k_euler.json")
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body stable solution simulation trace", save_path=None) #, save_path="threebodyeulervis.pdf")
numerical_analysis(states)

# %%
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=100000)
#save_states(f"states_3body_(dt{dt}st{int(n_steps/1000)}k_verlet.json", states)

# %%
#states = load_states("states_3body_(dt0.001st10000k_verlet.json")
plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), xlabel="x (m)", ylabel="y (m)", title="Three-body stable solution simulation trace", save_path=None)#, save_path="threebodyverletvis.pdf")
numerical_analysis(states)

# %%
#anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=40, scale=1.0, xlim=(-2.0, 2.0), ylim=(-2.0, 2.0), save_path=None) #save_path="3bodyproblem.gif")
#HTML(anim.to_jshtml())

# %%
#states = load_states("states_3body_extended.json")

# %%
#numerical_analysis(states)

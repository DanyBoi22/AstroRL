# %%
import numpy as np
import math
import json
import time
from IPython.display import HTML

from ipynb.fs.full.forcemodel import IForceModel, GravityForce
from ipynb.fs.full.integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from ipynb.fs.full.env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.helpers import save_states, load_states
from ipynb.fs.full.ship import SimpleImpulseShip, Maneuver, simple_action_space
from ipynb.fs.full.rlmontecarlo import train_mc, MonteCarloAgent, PolicyNet, compute_returns

# %%
# %load_ext line_profiler

# %% [markdown]
# Cool but unstable with really massive suns
# bodies = [
#     # Masses (kg)
#     np.array([
#         1.0e31,
#         1.0e31,
#         1.0e31,
#     ]),
#     # Positions (x, y) in meters
#     np.array([
#         [0.97e11, -0.243e11],
#         [-0.97e11, 0.243e11],
#         [0.0, 0.0],
#     ]),
#     # Velocities (vx, vy) in m/s
#     np.array([
#         [0.466e5, 0.432e5],
#         [0.466e5, 0.432e5],
#         [-0.932e5, -0.864e5],
#     ]),
#     # Names
#     np.array([
#         "One",
#         "Two",
#         "Three",
#     ]),
#     # Colors (reasonable defaults for visualization)
#     np.array([
#         "red",
#         "blue",
#         "green",
#     ]),
# ]

# %%
# This precompiles simulation for njit
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.243]
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432]
    ]),
    # Names
    np.array([
        "One",
        "Two"
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue"
    ]),
]
dt=0.0001
n_steps=1000
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=500)

# %% [markdown]
# # Monte Carlo RL with NN-Q Table #

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        7.342e22,       # Luna
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [3.844e8, 0.0],      # Luna
        [3.6e7, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 1022.0],          # Luna
        [0.0, 3055.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Moon",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "gray",       # Moon (Luna)
        "lightblue",  # Ship
    ]),
]

ship_index = len(bodies[0])-1
mass = bodies[0][-1]
thrust = 1e4 # thrust changes with dt so keep that in mind
actions = simple_action_space 
safety_radius = 1e4 # on a space scale 10 km is defenitely an atmo entry
escape_dist = 7e8   
escape_vel = 1e5 
target_dist = 1e5 # for a low lunar orbit
target_vel = 1700 # for a low lunar orbit
target_index = 1
pos_scale = 1e8
vel_scale = 1e4

ship = SimpleImpulseShip(ship_index=ship_index, mass=mass,thrust=thrust, actions=actions, safety_radius=safety_radius, escape_dist=escape_dist, escape_vel=escape_vel, target_dist=target_dist, target_vel=target_vel, target_index=target_index, pos_scale=pos_scale, vel_scale=vel_scale)

# %%
n_actions = actions.n
n_episodes=1000

dt=60.0
simulation_time = 3600 * 24 * 20
max_steps= int(simulation_time/dt)

env = SolarSystemEnv(GravityForce, VelocityVerlet, bodies, ship=ship, dt=dt)

obs0 = env.reset()
obs_dim = obs0.shape[0]

agent = MonteCarloAgent(obs_dim, n_actions)
states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=20, log_states=True, log_n_entries=400)
#%lprun -f MonteCarloAgent.update_policy -f MonteCarloAgent.run_episode train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_training_every=10, log_states=True, log_n_entries=400)
# Out:
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship exceeded escape velocity
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship escaped the system
# Ship exceeded escape velocity
# Ship escaped the system
# Episode   20 | Return: -8.185e+05 | Loss:  4.212e+02
# Ship exceeded escape velocity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      11 obs_dim = obs0.shape[0]
#      13 agent = MonteCarloAgent(obs_dim, n_actions)
# ---> 14 states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=20, log_states=True, log_n_entries=400)
#      15 #%lprun -f MonteCarloAgent.update_policy -f MonteCarloAgent.run_episode train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_training_every=10, log_states=True, log_n_entries=400)
#
# File D:\Desktop\jupo\rlmontecarlo.ipynb:156, in train_mc(env, agent, n_episodes, max_steps, log_every, log_states, log_n_entries)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "8b3e5b24-65e8-47ad-9982-2d1d00f67ea0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import math\n",
#      11     "import numpy as np\n",
#      12     "import torch\n",
#      13     "import torch.nn as nn\n",
#      14     "import torch.optim as optim\n",
#      15     "from torch.distributions import Categorical"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "542b12b8-50e4-441a-afba-9797d06747da",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "# hard coding visuals into training to see the changes online :3\n",
#      26     "from ipynb.fs.full.vis import plot_static_trajectories\n",
#      27     "bodies = [\n",
#      28     "    # Masses\n",
#      29     "    np.array([\n",
#      30     "        5.972e24,       # Earth\n",
#      31     "        7.342e22,       # Luna\n",
#      32     "        1.0e5,          # Ship\n",
#      33     "    ]),\n",
#      34     "    # Positions (x, y) in meters\n",
#      35     "    np.array([\n",
#      36     "        [0.0, 0.0],                # Earth\n",
#      37     "        [3.844e8, 0.0],      # Luna\n",
#      38     "        [3.6e7, 0.0],        # Ship\n",
#      39     "    ]),\n",
#      40     "    # Velocities (vx, vy) in m/s\n",
#      41     "    np.array([\n",
#      42     "        [0.0, 0.0],                   # Earth\n",
#      43     "        [0.0, 1022.0],          # Luna\n",
#      44     "        [0.0, 3055.0],         # Ship\n",
#      45     "    ]),\n",
#      46     "    # Names of celestial bodies\n",
#      47     "    np.array([\n",
#      48     "        \"Earth\",\n",
#      49     "        \"Moon\",\n",
#      50     "        \"Ship\"\n",
#      51     "    ]),\n",
#      52     "    # Colors for visuals\n",
#      53     "    np.array([\n",
#      54     "        \"blue\",       # Earth\n",
#      55     "        \"gray\",       # Moon (Luna)\n",
#      56     "        \"lightblue\",  # Ship\n",
#      57     "    ]),\n",
#      58     "]\n",
#      59     "scale=1.0/4e8\n",
#      60     "centre_body=\"Earth\"\n",
#      61     "xlim=(-1, 1)\n",
#      62     "ylim=(-1, 1)"
#      63    ]
#      64   },
#      65   {
#      66    "cell_type": "code",
#      67    "execution_count": 3,
#      68    "id": "8335d023-b61b-4197-83ad-5623cc6b97d5",
#      69    "metadata": {},
#      70    "outputs": [],
#      71    "source": [
#      72     "class PolicyNet(nn.Module):\n",
#      73     "    def __init__(self, obs_dim, n_actions, hidden=128):\n",
#      74     "        super().__init__()\n",
#      75     "        self.net = nn.Sequential(\n",
#      76     "            nn.Linear(obs_dim, hidden),\n",
#      77     "            nn.ReLU(),\n",
#      78     "            nn.Linear(hidden, hidden),\n",
#      79     "            nn.ReLU(),\n",
#      80     "            nn.Linear(hidden, n_actions)\n",
#      81     "        )\n",
#      82     "\n",
#      83     "    def forward(self, obs):\n",
#      84     "        logits = self.net(obs)\n",
#      85     "        return Categorical(logits=logits)"
#      86    ]
#      87   },
#      88   {
#      89    "cell_type": "code",
#      90    "execution_count": 4,
#      91    "id": "7e97263d-c311-4d8a-9597-e8bec5319f09",
#      92    "metadata": {},
#      93    "outputs": [],
#      94    "source": [
#      95     "def compute_returns(rewards, gamma):\n",
#      96     "    returns = []\n",
#      97     "    G = 0.0\n",
#      98     "    for r in reversed(rewards):\n",
#      99     "        G = r + gamma * G\n",
#     100     "        returns.append(G)\n",
#     101     "    returns.reverse()\n",
#     102     "    return torch.tensor(returns, dtype=torch.float32)"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": 5,
#     108    "id": "1921ef0b-d1ac-4ef8-8de6-eade1e8a0118",
#     109    "metadata": {},
#     110    "outputs": [],
#     111    "source": [
#     112     "class MonteCarloAgent:\n",
#     113     "    def __init__(self, obs_dim, n_actions, lr=3e-4, gamma=0.99, device=\"cpu\"):\n",
#     114     "        \n",
#     115     "        self.gamma = gamma\n",
#     116     "        self.device = device\n",
#     117     "\n",
#     118     "        self.policy = PolicyNet(obs_dim, n_actions).to(device)\n",
#     119     "        self.optimizer = optim.Adam(self.policy.parameters(), lr=lr)\n",
#     120     "\n",
#     121     "    def run_episode(self, env, max_steps=100000, log_states=False, log_n_entries=400):\n",
#     122     "        log_probs = []\n",
#     123     "        rewards = []\n",
#     124     "\n",
#     125     "        obs = env.reset()\n",
#     126     "        obs = torch.tensor(obs, dtype=torch.float32, device=self.device)\n",
#     127     "\n",
#     128     "        states = []\n",
#     129     "        if log_states:\n",
#     130     "            step = max(1, math.floor(max_steps / log_n_entries))\n",
#     131     "        else : \n",
#     132     "            step = 100\n",
#     133     "\n",
#     134     "        for i in range(max_steps):\n",
#     135     "            dist = self.policy(obs)\n",
#     136     "            action = dist.sample()\n",
#     137     "            log_prob = dist.log_prob(action)\n",
#     138     "            \n",
#     139     "            if log_states and i % step == 0:\n",
#     140     "                x, v, a, next_obs, reward, done = env.step(action.item())\n",
#     141     "                states.append({\"m\": env.m, \"x\": x, \"v\": v, \"a\": a, \"t\": env.t})\n",
#     142     "            else:\n",
#     143     "                _, _, _, next_obs, reward, done = env.step(action.item())\n",
#     144     "\n",
#     145     "            #print(f\"Log prob: {log_prob}\")\n",
#     146     "            #print(f\"Next_obs: {next_obs}\")\n",
#     147     "            #print(f\"Reward: {reward}\")\n",
#     148     "            #print(f\"Done: {done}\")\n",
#     149     "            \n",
#     150     "            log_probs.append(log_prob)\n",
#     151     "            rewards.append(reward)\n",
#     152     "\n",
#     153     "            obs = torch.tensor(next_obs, dtype=torch.float32, device=self.device)\n",
#     154     "\n",
#     155     "            if done:\n",
# --> 156     "                break\n",
#     157     "\n",
#     158     "            # exceeded max episode steps\n",
#     159     "            if i >= max_steps:\n",
#     160     "                break\n",
#     161     "                \n",
#     162     "        if log_states:\n",
#     163     "            return log_probs, rewards, states\n",
#     164     "        else: \n",
#     165     "            return log_probs, rewards\n",
#     166     "\n",
#     167     "\n",
#     168     "    def update_policy(self, log_probs, rewards):\n",
#     169     "        returns = compute_returns(rewards, self.gamma).to(self.device)\n",
#     170     "\n",
#     171     "        # normalize returns (important for stability)\n",
#     172     "        returns = (returns - returns.mean()) / (returns.std() + 1e-8)\n",
#     173     "\n",
#     174     "        loss = 0.0\n",
#     175     "        for log_prob, G in zip(log_probs, returns):\n",
#     176     "            loss += -log_prob * G\n",
#     177     "\n",
#     178     "        self.optimizer.zero_grad()\n",
#     179     "        loss.backward()\n",
#     180     "        self.optimizer.step()\n",
#     181     "\n",
#     182     "        return loss.item()"
#     183    ]
#     184   },
#     185   {
#     186    "cell_type": "code",
#     187    "execution_count": 6,
#     188    "id": "aa3f6bb2-d851-4550-b3a5-9ba8aa77a96a",
#     189    "metadata": {},
#     190    "outputs": [],
#     191    "source": [
#     192     "def train_mc(env, agent, n_episodes=1000, max_steps=100000, log_every=10, log_states=False, log_n_entries=400):\n",
#     193     "    states_list = []\n",
#     194     "    for ep in range(1, n_episodes + 1):\n",
#     195     "        if log_states and ep % log_every == 0:\n",
#     196     "            log_probs, rewards, states = agent.run_episode(env, max_steps, log_states, log_n_entries)\n",
#     197     "        else:\n",
#     198     "            log_probs, rewards = agent.run_episode(env, max_steps)\n",
#     199     "        \n",
#     200     "        loss = agent.update_policy(log_probs, rewards)\n",
#     201     "\n",
#     202     "        total_reward = sum(rewards)\n",
#     203     "\n",
#     204     "        if ep % log_every == 0:\n",
#     205     "            print(\n",
#     206     "                f\"Episode {ep:4d} | \"\n",
#     207     "                f\"Return: {total_reward: .3e} | \"\n",
#     208     "                f\"Loss: {loss: .3e}\"\n",
#     209     "            )\n",
#     210     "            if log_states:\n",
#     211     "                states_list.append(states)\n",
#     212     "                \n",
#     213     "                # hard coding visuals into training to see the changes online :3\n",
#     214     "                plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)\n",
#     215     "\n",
#     216     "    return states_list"
#     217    ]
#     218   },
#     219   {
#     220    "cell_type": "code",
#     221    "execution_count": null,
#     222    "id": "79bbda78-35a6-4fe0-8dd9-6c4a7ea9d6e7",
#     223    "metadata": {},
#     224    "outputs": [],
#     225    "source": []
#     226   }
#     227  ],
#     228  "metadata": {
#     229   "kernelspec": {
#     230    "display_name": "Python 3 (ipykernel)",
#     231    "language": "python",
#     232    "name": "python3"
#     233   },
#     234   "language_info": {
#     235    "codemirror_mode": {
#     236     "name": "ipython",
#     237     "version": 3
#     238    },
#     239    "file_extension": ".py",
#     240    "mimetype": "text/x-python",
#     241    "name": "python",
#     242    "nbconvert_exporter": "python",
#     243    "pygments_lexer": "ipython3",
#     244    "version": "3.11.5"
#     245   }
#     246  },
#     247  "nbformat": 4,
#     248  "nbformat_minor": 5
#     249 }
#
# File D:\Desktop\jupo\rlmontecarlo.ipynb:143, in update_policy(self, log_probs, rewards)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "8b3e5b24-65e8-47ad-9982-2d1d00f67ea0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import math\n",
#      11     "import numpy as np\n",
#      12     "import torch\n",
#      13     "import torch.nn as nn\n",
#      14     "import torch.optim as optim\n",
#      15     "from torch.distributions import Categorical"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 2,
#      21    "id": "542b12b8-50e4-441a-afba-9797d06747da",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "# hard coding visuals into training to see the changes online :3\n",
#      26     "from ipynb.fs.full.vis import plot_static_trajectories\n",
#      27     "bodies = [\n",
#      28     "    # Masses\n",
#      29     "    np.array([\n",
#      30     "        5.972e24,       # Earth\n",
#      31     "        7.342e22,       # Luna\n",
#      32     "        1.0e5,          # Ship\n",
#      33     "    ]),\n",
#      34     "    # Positions (x, y) in meters\n",
#      35     "    np.array([\n",
#      36     "        [0.0, 0.0],                # Earth\n",
#      37     "        [3.844e8, 0.0],      # Luna\n",
#      38     "        [3.6e7, 0.0],        # Ship\n",
#      39     "    ]),\n",
#      40     "    # Velocities (vx, vy) in m/s\n",
#      41     "    np.array([\n",
#      42     "        [0.0, 0.0],                   # Earth\n",
#      43     "        [0.0, 1022.0],          # Luna\n",
#      44     "        [0.0, 3055.0],         # Ship\n",
#      45     "    ]),\n",
#      46     "    # Names of celestial bodies\n",
#      47     "    np.array([\n",
#      48     "        \"Earth\",\n",
#      49     "        \"Moon\",\n",
#      50     "        \"Ship\"\n",
#      51     "    ]),\n",
#      52     "    # Colors for visuals\n",
#      53     "    np.array([\n",
#      54     "        \"blue\",       # Earth\n",
#      55     "        \"gray\",       # Moon (Luna)\n",
#      56     "        \"lightblue\",  # Ship\n",
#      57     "    ]),\n",
#      58     "]\n",
#      59     "scale=1.0/4e8\n",
#      60     "centre_body=\"Earth\"\n",
#      61     "xlim=(-1, 1)\n",
#      62     "ylim=(-1, 1)"
#      63    ]
#      64   },
#      65   {
#      66    "cell_type": "code",
#      67    "execution_count": 3,
#      68    "id": "8335d023-b61b-4197-83ad-5623cc6b97d5",
#      69    "metadata": {},
#      70    "outputs": [],
#      71    "source": [
#      72     "class PolicyNet(nn.Module):\n",
#      73     "    def __init__(self, obs_dim, n_actions, hidden=128):\n",
#      74     "        super().__init__()\n",
#      75     "        self.net = nn.Sequential(\n",
#      76     "            nn.Linear(obs_dim, hidden),\n",
#      77     "            nn.ReLU(),\n",
#      78     "            nn.Linear(hidden, hidden),\n",
#      79     "            nn.ReLU(),\n",
#      80     "            nn.Linear(hidden, n_actions)\n",
#      81     "        )\n",
#      82     "\n",
#      83     "    def forward(self, obs):\n",
#      84     "        logits = self.net(obs)\n",
#      85     "        return Categorical(logits=logits)"
#      86    ]
#      87   },
#      88   {
#      89    "cell_type": "code",
#      90    "execution_count": 4,
#      91    "id": "7e97263d-c311-4d8a-9597-e8bec5319f09",
#      92    "metadata": {},
#      93    "outputs": [],
#      94    "source": [
#      95     "def compute_returns(rewards, gamma):\n",
#      96     "    returns = []\n",
#      97     "    G = 0.0\n",
#      98     "    for r in reversed(rewards):\n",
#      99     "        G = r + gamma * G\n",
#     100     "        returns.append(G)\n",
#     101     "    returns.reverse()\n",
#     102     "    return torch.tensor(returns, dtype=torch.float32)"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": 5,
#     108    "id": "1921ef0b-d1ac-4ef8-8de6-eade1e8a0118",
#     109    "metadata": {},
#     110    "outputs": [],
#     111    "source": [
#     112     "class MonteCarloAgent:\n",
#     113     "    def __init__(self, obs_dim, n_actions, lr=3e-4, gamma=0.99, device=\"cpu\"):\n",
#     114     "        \n",
#     115     "        self.gamma = gamma\n",
#     116     "        self.device = device\n",
#     117     "\n",
#     118     "        self.policy = PolicyNet(obs_dim, n_actions).to(device)\n",
#     119     "        self.optimizer = optim.Adam(self.policy.parameters(), lr=lr)\n",
#     120     "\n",
#     121     "    def run_episode(self, env, max_steps=100000, log_states=False, log_n_entries=400):\n",
#     122     "        log_probs = []\n",
#     123     "        rewards = []\n",
#     124     "\n",
#     125     "        obs = env.reset()\n",
#     126     "        obs = torch.tensor(obs, dtype=torch.float32, device=self.device)\n",
#     127     "\n",
#     128     "        states = []\n",
#     129     "        if log_states:\n",
#     130     "            step = max(1, math.floor(max_steps / log_n_entries))\n",
#     131     "        else : \n",
#     132     "            step = 100\n",
#     133     "\n",
#     134     "        for i in range(max_steps):\n",
#     135     "            dist = self.policy(obs)\n",
#     136     "            action = dist.sample()\n",
#     137     "            log_prob = dist.log_prob(action)\n",
#     138     "            \n",
#     139     "            if log_states and i % step == 0:\n",
#     140     "                x, v, a, next_obs, reward, done = env.step(action.item())\n",
#     141     "                states.append({\"m\": env.m, \"x\": x, \"v\": v, \"a\": a, \"t\": env.t})\n",
#     142     "            else:\n",
# --> 143     "                _, _, _, next_obs, reward, done = env.step(action.item())\n",
#     144     "\n",
#     145     "            #print(f\"Log prob: {log_prob}\")\n",
#     146     "            #print(f\"Next_obs: {next_obs}\")\n",
#     147     "            #print(f\"Reward: {reward}\")\n",
#     148     "            #print(f\"Done: {done}\")\n",
#     149     "            \n",
#     150     "            log_probs.append(log_prob)\n",
#     151     "            rewards.append(reward)\n",
#     152     "\n",
#     153     "            obs = torch.tensor(next_obs, dtype=torch.float32, device=self.device)\n",
#     154     "\n",
#     155     "            if done:\n",
#     156     "                break\n",
#     157     "\n",
#     158     "            # exceeded max episode steps\n",
#     159     "            if i >= max_steps:\n",
#     160     "                break\n",
#     161     "                \n",
#     162     "        if log_states:\n",
#     163     "            return log_probs, rewards, states\n",
#     164     "        else: \n",
#     165     "            return log_probs, rewards\n",
#     166     "\n",
#     167     "\n",
#     168     "    def update_policy(self, log_probs, rewards):\n",
#     169     "        returns = compute_returns(rewards, self.gamma).to(self.device)\n",
#     170     "\n",
#     171     "        # normalize returns (important for stability)\n",
#     172     "        returns = (returns - returns.mean()) / (returns.std() + 1e-8)\n",
#     173     "\n",
#     174     "        loss = 0.0\n",
#     175     "        for log_prob, G in zip(log_probs, returns):\n",
#     176     "            loss += -log_prob * G\n",
#     177     "\n",
#     178     "        self.optimizer.zero_grad()\n",
#     179     "        loss.backward()\n",
#     180     "        self.optimizer.step()\n",
#     181     "\n",
#     182     "        return loss.item()"
#     183    ]
#     184   },
#     185   {
#     186    "cell_type": "code",
#     187    "execution_count": 6,
#     188    "id": "aa3f6bb2-d851-4550-b3a5-9ba8aa77a96a",
#     189    "metadata": {},
#     190    "outputs": [],
#     191    "source": [
#     192     "def train_mc(env, agent, n_episodes=1000, max_steps=100000, log_every=10, log_states=False, log_n_entries=400):\n",
#     193     "    states_list = []\n",
#     194     "    for ep in range(1, n_episodes + 1):\n",
#     195     "        if log_states and ep % log_every == 0:\n",
#     196     "            log_probs, rewards, states = agent.run_episode(env, max_steps, log_states, log_n_entries)\n",
#     197     "        else:\n",
#     198     "            log_probs, rewards = agent.run_episode(env, max_steps)\n",
#     199     "        \n",
#     200     "        loss = agent.update_policy(log_probs, rewards)\n",
#     201     "\n",
#     202     "        total_reward = sum(rewards)\n",
#     203     "\n",
#     204     "        if ep % log_every == 0:\n",
#     205     "            print(\n",
#     206     "                f\"Episode {ep:4d} | \"\n",
#     207     "                f\"Return: {total_reward: .3e} | \"\n",
#     208     "                f\"Loss: {loss: .3e}\"\n",
#     209     "            )\n",
#     210     "            if log_states:\n",
#     211     "                states_list.append(states)\n",
#     212     "                \n",
#     213     "                # hard coding visuals into training to see the changes online :3\n",
#     214     "                plot_static_trajectories(states=states, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)\n",
#     215     "\n",
#     216     "    return states_list"
#     217    ]
#     218   },
#     219   {
#     220    "cell_type": "code",
#     221    "execution_count": null,
#     222    "id": "79bbda78-35a6-4fe0-8dd9-6c4a7ea9d6e7",
#     223    "metadata": {},
#     224    "outputs": [],
#     225    "source": []
#     226   }
#     227  ],
#     228  "metadata": {
#     229   "kernelspec": {
#     230    "display_name": "Python 3 (ipykernel)",
#     231    "language": "python",
#     232    "name": "python3"
#     233   },
#     234   "language_info": {
#     235    "codemirror_mode": {
#     236     "name": "ipython",
#     237     "version": 3
#     238    },
#     239    "file_extension": ".py",
#     240    "mimetype": "text/x-python",
#     241    "name": "python",
#     242    "nbconvert_exporter": "python",
#     243    "pygments_lexer": "ipython3",
#     244    "version": "3.11.5"
#     245   }
#     246  },
#     247  "nbformat": 4,
#     248  "nbformat_minor": 5
#     249 }
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
scale=1.0/4e8
centre_body="Earth"
xlim=(-1, 1)
ylim=(-1, 1)

for states_dict in states: 
#    plot_static_trajectories(states=states_dict, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)

# %%
#anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=20, scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim, save_path="mcrl.gif")
#HTML(anim.to_jshtml())

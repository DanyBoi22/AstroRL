# %%
import numpy as np
import math
import json
import time
from IPython.display import HTML

from ipynb.fs.full.forcemodel import IForceModel, GravityForce
from ipynb.fs.full.integrator import IIntegrator, SymplecticEuler, VelocityVerlet
from ipynb.fs.full.env import SolarSystemEnv, run_simulation, run_script_simulation, adjust_barycentric
from ipynb.fs.full.vis import visualize_trajectories, plot_static_trajectories
from ipynb.fs.full.helpers import save_states, load_states
from ipynb.fs.full.ship import SimpleImpulseShip, Maneuver, simple_action_space
from ipynb.fs.full.rlmontecarlo import train_mc, MonteCarloAgent, PolicyNet, compute_returns

# %%
# %load_ext line_profiler

# %% [markdown]
# Cool but unstable with really massive suns
# bodies = [
#     # Masses (kg)
#     np.array([
#         1.0e31,
#         1.0e31,
#         1.0e31,
#     ]),
#     # Positions (x, y) in meters
#     np.array([
#         [0.97e11, -0.243e11],
#         [-0.97e11, 0.243e11],
#         [0.0, 0.0],
#     ]),
#     # Velocities (vx, vy) in m/s
#     np.array([
#         [0.466e5, 0.432e5],
#         [0.466e5, 0.432e5],
#         [-0.932e5, -0.864e5],
#     ]),
#     # Names
#     np.array([
#         "One",
#         "Two",
#         "Three",
#     ]),
#     # Colors (reasonable defaults for visualization)
#     np.array([
#         "red",
#         "blue",
#         "green",
#     ]),
# ]

# %%
# This precompiles simulation for njit
bodies = [
    # Masses (kg)
    np.array([
        1.5e10,
        1.5e10
    ]),
    # Positions (x, y) in meters (approx semi-major axes on x-axis)
    np.array([
        [0.97, -0.243],
        [-0.97, 0.243]
    ]),
    # Velocities (vx, vy) in m/s (circular orbit approximation)
    np.array([
        [0.466, 0.432],
        [0.466, 0.432]
    ]),
    # Names
    np.array([
        "One",
        "Two"
    ]),
    # Colors (reasonable defaults for visualization)
    np.array([
        "red",
        "blue"
    ]),
]
dt=0.0001
n_steps=1000
states = run_simulation(GravityForce, VelocityVerlet, bodies, dt=dt, n_steps=n_steps, records_len=500)

# %% [markdown]
# # Monte Carlo RL with NN-Q Table #

# %%
bodies = [
    # Masses
    np.array([
        5.972e24,       # Earth
        7.342e22,       # Luna
        1.0e5,          # Ship
    ]),
    # Positions (x, y) in meters
    np.array([
        [0.0, 0.0],                # Earth
        [3.844e8, 0.0],      # Luna
        [3.6e7, 0.0],        # Ship
    ]),
    # Velocities (vx, vy) in m/s
    np.array([
        [0.0, 0.0],                   # Earth
        [0.0, 1022.0],          # Luna
        [0.0, 3055.0],         # Ship
    ]),
    # Names of celestial bodies
    np.array([
        "Earth",
        "Moon",
        "Ship"
    ]),
    # Colors for visuals
    np.array([
        "blue",       # Earth
        "gray",       # Moon (Luna)
        "lightblue",  # Ship
    ]),
]

ship_index = len(bodies[0])-1
mass = bodies[0][-1]
thrust = 1e4 # thrust changes with dt so keep that in mind
actions = simple_action_space 
safety_radius = 1e4 # on a space scale 10 km is defenitely an atmo entry
escape_dist = 1e9   
escape_vel = 1e5 
target_dist = 1e5 # for a low lunar orbit
target_vel = 1700 # for a low lunar orbit
target_index = 1
pos_scale = 1e8
vel_scale = 1e4

ship = SimpleImpulseShip(ship_index=ship_index, mass=mass,thrust=thrust, actions=actions, safety_radius=safety_radius, escape_dist=escape_dist, escape_vel=escape_vel, target_dist=target_dist, target_vel=target_vel, target_index=target_index, pos_scale=pos_scale, vel_scale=vel_scale)

# %%
dt=60.0
n_actions = 5
n_episodes=200
max_steps=10000

env = SolarSystemEnv(GravityForce, VelocityVerlet, bodies, ship=ship, dt=dt)

obs0 = env.reset()
obs_dim = obs0.shape[0]

agent = MonteCarloAgent(obs_dim, n_actions)
states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=10, log_states=True, log_n_entries=400)
#%lprun -f MonteCarloAgent.update_policy -f MonteCarloAgent.run_episode train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_training_every=10, log_states=True, log_n_entries=400)
# Out:
# C:\Users\khoma\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:215: UserWarning:
# NVIDIA GeForce RTX 5070 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90 compute_37.
# If you want to use the NVIDIA GeForce RTX 5070 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       9 obs_dim = obs0.shape[0]
#      11 agent = MonteCarloAgent(obs_dim, n_actions)
# ---> 12 states = train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_every=10, log_states=True, log_n_entries=400)
#      13 #%lprun -f MonteCarloAgent.update_policy -f MonteCarloAgent.run_episode train_mc(env, agent, n_episodes=n_episodes, max_steps=max_steps, log_training_every=10, log_states=True, log_n_entries=400)
#
# File D:\Desktop\jupo\rlmontecarlo.ipynb:116, in train_mc(env, agent, n_episodes, max_steps, log_every, log_states, log_n_entries)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "8b3e5b24-65e8-47ad-9982-2d1d00f67ea0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import math\n",
#      11     "import torch\n",
#      12     "import torch.nn as nn\n",
#      13     "import torch.optim as optim\n",
#      14     "from torch.distributions import Categorical"
#      15    ]
#      16   },
#      17   {
#      18    "cell_type": "code",
#      19    "execution_count": 2,
#      20    "id": "8335d023-b61b-4197-83ad-5623cc6b97d5",
#      21    "metadata": {},
#      22    "outputs": [],
#      23    "source": [
#      24     "class PolicyNet(nn.Module):\n",
#      25     "    def __init__(self, obs_dim, n_actions, hidden=128):\n",
#      26     "        super().__init__()\n",
#      27     "        self.net = nn.Sequential(\n",
#      28     "            nn.Linear(obs_dim, hidden),\n",
#      29     "            nn.ReLU(),\n",
#      30     "            nn.Linear(hidden, hidden),\n",
#      31     "            nn.ReLU(),\n",
#      32     "            nn.Linear(hidden, n_actions)\n",
#      33     "        )\n",
#      34     "\n",
#      35     "    def forward(self, obs):\n",
#      36     "        logits = self.net(obs)\n",
#      37     "        return Categorical(logits=logits)"
#      38    ]
#      39   },
#      40   {
#      41    "cell_type": "code",
#      42    "execution_count": 3,
#      43    "id": "7e97263d-c311-4d8a-9597-e8bec5319f09",
#      44    "metadata": {},
#      45    "outputs": [],
#      46    "source": [
#      47     "def compute_returns(rewards, gamma):\n",
#      48     "    returns = []\n",
#      49     "    G = 0.0\n",
#      50     "    for r in reversed(rewards):\n",
#      51     "        G = r + gamma * G\n",
#      52     "        returns.append(G)\n",
#      53     "    returns.reverse()\n",
#      54     "    return torch.tensor(returns, dtype=torch.float32)"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": 4,
#      60    "id": "1921ef0b-d1ac-4ef8-8de6-eade1e8a0118",
#      61    "metadata": {},
#      62    "outputs": [],
#      63    "source": [
#      64     "class MonteCarloAgent:\n",
#      65     "    def __init__(self, obs_dim, n_actions, lr=3e-4, gamma=0.99, device=\"cuda\"):\n",
#      66     "        \n",
#      67     "        self.gamma = gamma\n",
#      68     "        self.device = device\n",
#      69     "\n",
#      70     "        self.policy = PolicyNet(obs_dim, n_actions).to(device)\n",
#      71     "        self.optimizer = optim.Adam(self.policy.parameters(), lr=lr)\n",
#      72     "\n",
#      73     "    def run_episode(self, env, max_steps=100000, log_states=False, log_n_entries=400):\n",
#      74     "        log_probs = []\n",
#      75     "        rewards = []\n",
#      76     "\n",
#      77     "        obs = env.reset()\n",
#      78     "        obs = torch.tensor(obs, dtype=torch.float32, device=self.device)\n",
#      79     "\n",
#      80     "        states = []\n",
#      81     "        if log_states:\n",
#      82     "            step = max(1, math.floor(max_steps / log_n_entries))\n",
#      83     "        else : \n",
#      84     "            step = 100\n",
#      85     "\n",
#      86     "        for i in range(max_steps):\n",
#      87     "            dist = self.policy(obs)\n",
#      88     "            action = dist.sample()\n",
#      89     "            log_prob = dist.log_prob(action)\n",
#      90     "            \n",
#      91     "            if log_states and i % step == 0:\n",
#      92     "                x, v, a, next_obs, reward, done = env.step(action.item())\n",
#      93     "                states.append({\"m\": env.m, \"x\": x, \"v\": v, \"a\": a, \"t\": env.t})\n",
#      94     "            else:\n",
#      95     "                _, _, _, next_obs, reward, done = env.step(action.item())\n",
#      96     "\n",
#      97     "            #print(f\"Log prob: {log_prob}\")\n",
#      98     "            #print(f\"Next_obs: {next_obs}\")\n",
#      99     "            #print(f\"Reward: {reward}\")\n",
#     100     "            #print(f\"Done: {done}\")\n",
#     101     "            \n",
#     102     "            log_probs.append(log_prob)\n",
#     103     "            rewards.append(reward)\n",
#     104     "\n",
#     105     "            obs = torch.tensor(next_obs, dtype=torch.float32, device=self.device)\n",
#     106     "\n",
#     107     "            if done:\n",
#     108     "                break\n",
#     109     "\n",
#     110     "            # exceeded max episode steps\n",
#     111     "            if i >= max_steps:\n",
#     112     "                break\n",
#     113     "                \n",
#     114     "        if log_states:\n",
#     115     "            return log_probs, rewards, states\n",
# --> 116     "        else: \n",
#     117     "            return log_probs, rewards\n",
#     118     "\n",
#     119     "\n",
#     120     "    def update_policy(self, log_probs, rewards):\n",
#     121     "        returns = compute_returns(rewards, self.gamma).to(self.device)\n",
#     122     "\n",
#     123     "        # normalize returns (important for stability)\n",
#     124     "        returns = (returns - returns.mean()) / (returns.std() + 1e-8)\n",
#     125     "\n",
#     126     "        loss = 0.0\n",
#     127     "        for log_prob, G in zip(log_probs, returns):\n",
#     128     "            loss += -log_prob * G\n",
#     129     "\n",
#     130     "        self.optimizer.zero_grad()\n",
#     131     "        loss.backward()\n",
#     132     "        self.optimizer.step()\n",
#     133     "\n",
#     134     "        return loss.item()"
#     135    ]
#     136   },
#     137   {
#     138    "cell_type": "code",
#     139    "execution_count": 5,
#     140    "id": "aa3f6bb2-d851-4550-b3a5-9ba8aa77a96a",
#     141    "metadata": {},
#     142    "outputs": [],
#     143    "source": [
#     144     "def train_mc(env, agent, n_episodes=1000, max_steps=100000, log_every=10, log_states=False, log_n_entries=400):\n",
#     145     "    states_list = []\n",
#     146     "    for ep in range(1, n_episodes + 1):\n",
#     147     "        if log_states and ep % log_every == 0:\n",
#     148     "            log_probs, rewards, states = agent.run_episode(env, max_steps, log_states, log_n_entries)\n",
#     149     "        else:\n",
#     150     "            log_probs, rewards = agent.run_episode(env, max_steps)\n",
#     151     "        \n",
#     152     "        loss = agent.update_policy(log_probs, rewards)\n",
#     153     "\n",
#     154     "        total_reward = sum(rewards)\n",
#     155     "\n",
#     156     "        if ep % log_every == 0:\n",
#     157     "            print(\n",
#     158     "                f\"Episode {ep:4d} | \"\n",
#     159     "                f\"Return: {total_reward: .3e} | \"\n",
#     160     "                f\"Loss: {loss: .3e}\"\n",
#     161     "            )\n",
#     162     "            if log_states:\n",
#     163     "                states_list.append(states)\n",
#     164     "\n",
#     165     "    return states_list"
#     166    ]
#     167   },
#     168   {
#     169    "cell_type": "code",
#     170    "execution_count": null,
#     171    "id": "79bbda78-35a6-4fe0-8dd9-6c4a7ea9d6e7",
#     172    "metadata": {},
#     173    "outputs": [],
#     174    "source": []
#     175   }
#     176  ],
#     177  "metadata": {
#     178   "kernelspec": {
#     179    "display_name": "Python 3 (ipykernel)",
#     180    "language": "python",
#     181    "name": "python3"
#     182   },
#     183   "language_info": {
#     184    "codemirror_mode": {
#     185     "name": "ipython",
#     186     "version": 3
#     187    },
#     188    "file_extension": ".py",
#     189    "mimetype": "text/x-python",
#     190    "name": "python",
#     191    "nbconvert_exporter": "python",
#     192    "pygments_lexer": "ipython3",
#     193    "version": "3.11.5"
#     194   }
#     195  },
#     196  "nbformat": 4,
#     197  "nbformat_minor": 5
#     198 }
#
# File D:\Desktop\jupo\rlmontecarlo.ipynb:103, in update_policy(self, log_probs, rewards)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "8b3e5b24-65e8-47ad-9982-2d1d00f67ea0",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import math\n",
#      11     "import torch\n",
#      12     "import torch.nn as nn\n",
#      13     "import torch.optim as optim\n",
#      14     "from torch.distributions import Categorical"
#      15    ]
#      16   },
#      17   {
#      18    "cell_type": "code",
#      19    "execution_count": 2,
#      20    "id": "8335d023-b61b-4197-83ad-5623cc6b97d5",
#      21    "metadata": {},
#      22    "outputs": [],
#      23    "source": [
#      24     "class PolicyNet(nn.Module):\n",
#      25     "    def __init__(self, obs_dim, n_actions, hidden=128):\n",
#      26     "        super().__init__()\n",
#      27     "        self.net = nn.Sequential(\n",
#      28     "            nn.Linear(obs_dim, hidden),\n",
#      29     "            nn.ReLU(),\n",
#      30     "            nn.Linear(hidden, hidden),\n",
#      31     "            nn.ReLU(),\n",
#      32     "            nn.Linear(hidden, n_actions)\n",
#      33     "        )\n",
#      34     "\n",
#      35     "    def forward(self, obs):\n",
#      36     "        logits = self.net(obs)\n",
#      37     "        return Categorical(logits=logits)"
#      38    ]
#      39   },
#      40   {
#      41    "cell_type": "code",
#      42    "execution_count": 3,
#      43    "id": "7e97263d-c311-4d8a-9597-e8bec5319f09",
#      44    "metadata": {},
#      45    "outputs": [],
#      46    "source": [
#      47     "def compute_returns(rewards, gamma):\n",
#      48     "    returns = []\n",
#      49     "    G = 0.0\n",
#      50     "    for r in reversed(rewards):\n",
#      51     "        G = r + gamma * G\n",
#      52     "        returns.append(G)\n",
#      53     "    returns.reverse()\n",
#      54     "    return torch.tensor(returns, dtype=torch.float32)"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": 4,
#      60    "id": "1921ef0b-d1ac-4ef8-8de6-eade1e8a0118",
#      61    "metadata": {},
#      62    "outputs": [],
#      63    "source": [
#      64     "class MonteCarloAgent:\n",
#      65     "    def __init__(self, obs_dim, n_actions, lr=3e-4, gamma=0.99, device=\"cuda\"):\n",
#      66     "        \n",
#      67     "        self.gamma = gamma\n",
#      68     "        self.device = device\n",
#      69     "\n",
#      70     "        self.policy = PolicyNet(obs_dim, n_actions).to(device)\n",
#      71     "        self.optimizer = optim.Adam(self.policy.parameters(), lr=lr)\n",
#      72     "\n",
#      73     "    def run_episode(self, env, max_steps=100000, log_states=False, log_n_entries=400):\n",
#      74     "        log_probs = []\n",
#      75     "        rewards = []\n",
#      76     "\n",
#      77     "        obs = env.reset()\n",
#      78     "        obs = torch.tensor(obs, dtype=torch.float32, device=self.device)\n",
#      79     "\n",
#      80     "        states = []\n",
#      81     "        if log_states:\n",
#      82     "            step = max(1, math.floor(max_steps / log_n_entries))\n",
#      83     "        else : \n",
#      84     "            step = 100\n",
#      85     "\n",
#      86     "        for i in range(max_steps):\n",
#      87     "            dist = self.policy(obs)\n",
#      88     "            action = dist.sample()\n",
#      89     "            log_prob = dist.log_prob(action)\n",
#      90     "            \n",
#      91     "            if log_states and i % step == 0:\n",
#      92     "                x, v, a, next_obs, reward, done = env.step(action.item())\n",
#      93     "                states.append({\"m\": env.m, \"x\": x, \"v\": v, \"a\": a, \"t\": env.t})\n",
#      94     "            else:\n",
#      95     "                _, _, _, next_obs, reward, done = env.step(action.item())\n",
#      96     "\n",
#      97     "            #print(f\"Log prob: {log_prob}\")\n",
#      98     "            #print(f\"Next_obs: {next_obs}\")\n",
#      99     "            #print(f\"Reward: {reward}\")\n",
#     100     "            #print(f\"Done: {done}\")\n",
#     101     "            \n",
#     102     "            log_probs.append(log_prob)\n",
# --> 103     "            rewards.append(reward)\n",
#     104     "\n",
#     105     "            obs = torch.tensor(next_obs, dtype=torch.float32, device=self.device)\n",
#     106     "\n",
#     107     "            if done:\n",
#     108     "                break\n",
#     109     "\n",
#     110     "            # exceeded max episode steps\n",
#     111     "            if i >= max_steps:\n",
#     112     "                break\n",
#     113     "                \n",
#     114     "        if log_states:\n",
#     115     "            return log_probs, rewards, states\n",
#     116     "        else: \n",
#     117     "            return log_probs, rewards\n",
#     118     "\n",
#     119     "\n",
#     120     "    def update_policy(self, log_probs, rewards):\n",
#     121     "        returns = compute_returns(rewards, self.gamma).to(self.device)\n",
#     122     "\n",
#     123     "        # normalize returns (important for stability)\n",
#     124     "        returns = (returns - returns.mean()) / (returns.std() + 1e-8)\n",
#     125     "\n",
#     126     "        loss = 0.0\n",
#     127     "        for log_prob, G in zip(log_probs, returns):\n",
#     128     "            loss += -log_prob * G\n",
#     129     "\n",
#     130     "        self.optimizer.zero_grad()\n",
#     131     "        loss.backward()\n",
#     132     "        self.optimizer.step()\n",
#     133     "\n",
#     134     "        return loss.item()"
#     135    ]
#     136   },
#     137   {
#     138    "cell_type": "code",
#     139    "execution_count": 5,
#     140    "id": "aa3f6bb2-d851-4550-b3a5-9ba8aa77a96a",
#     141    "metadata": {},
#     142    "outputs": [],
#     143    "source": [
#     144     "def train_mc(env, agent, n_episodes=1000, max_steps=100000, log_every=10, log_states=False, log_n_entries=400):\n",
#     145     "    states_list = []\n",
#     146     "    for ep in range(1, n_episodes + 1):\n",
#     147     "        if log_states and ep % log_every == 0:\n",
#     148     "            log_probs, rewards, states = agent.run_episode(env, max_steps, log_states, log_n_entries)\n",
#     149     "        else:\n",
#     150     "            log_probs, rewards = agent.run_episode(env, max_steps)\n",
#     151     "        \n",
#     152     "        loss = agent.update_policy(log_probs, rewards)\n",
#     153     "\n",
#     154     "        total_reward = sum(rewards)\n",
#     155     "\n",
#     156     "        if ep % log_every == 0:\n",
#     157     "            print(\n",
#     158     "                f\"Episode {ep:4d} | \"\n",
#     159     "                f\"Return: {total_reward: .3e} | \"\n",
#     160     "                f\"Loss: {loss: .3e}\"\n",
#     161     "            )\n",
#     162     "            if log_states:\n",
#     163     "                states_list.append(states)\n",
#     164     "\n",
#     165     "    return states_list"
#     166    ]
#     167   },
#     168   {
#     169    "cell_type": "code",
#     170    "execution_count": null,
#     171    "id": "79bbda78-35a6-4fe0-8dd9-6c4a7ea9d6e7",
#     172    "metadata": {},
#     173    "outputs": [],
#     174    "source": []
#     175   }
#     176  ],
#     177  "metadata": {
#     178   "kernelspec": {
#     179    "display_name": "Python 3 (ipykernel)",
#     180    "language": "python",
#     181    "name": "python3"
#     182   },
#     183   "language_info": {
#     184    "codemirror_mode": {
#     185     "name": "ipython",
#     186     "version": 3
#     187    },
#     188    "file_extension": ".py",
#     189    "mimetype": "text/x-python",
#     190    "name": "python",
#     191    "nbconvert_exporter": "python",
#     192    "pygments_lexer": "ipython3",
#     193    "version": "3.11.5"
#     194   }
#     195  },
#     196  "nbformat": 4,
#     197  "nbformat_minor": 5
#     198 }
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
scale=1.0/4e8
centre_body="Earth"
xlim=(-1, 1)
ylim=(-1, 1)

for states_dict in states: 
    plot_static_trajectories(states=states_dict, body_names=bodies[3], colors=bodies[4], scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim)

# %%
anim = visualize_trajectories(states=states, body_names=bodies[3], colors=bodies[4], interval=20, scale=scale, centre_body=centre_body, xlim=xlim, ylim=ylim, save_path="mcrl.gif")
#HTML(anim.to_jshtml())
